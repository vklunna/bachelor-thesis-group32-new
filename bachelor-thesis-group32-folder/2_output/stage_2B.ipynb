# %%
# Ensure you're on the correct kernel (e.g. 'esg-py311')
import sys
from pathlib import Path
import pandas as pd

# 2) Point to your 1_code folder so we can import the run() function
#    If auto‑detect fails, manually set REPO_ROOT to the folder containing both '1_code' and '2_output'
# 2) Auto‑detect the repo root by climbing until we see '2_output/extracted_tables'
REPO_ROOT = Path().resolve()
while True:
    if (REPO_ROOT / '2_output' / 'extracted_tables').exists():
        break
    if REPO_ROOT.parent == REPO_ROOT:
        raise RuntimeError("Couldn't locate '2_output/extracted_tables' in any parent")
    REPO_ROOT = REPO_ROOT.parent
print(f"Using REPO_ROOT = {REPO_ROOT}")

sys.path.append(str(REPO_ROOT / '1_code'))

from stage2B import run   # import the existing main() entrypoint
# Out:
# Using REPO_ROOT = /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder

# %%
# Point to the folder where Stage2A dumped all extracted tables:
# It should contain subfolders for each report (e.g. 'vinci-2024-universal-registration-document')
extracted_root = REPO_ROOT / '2_output' / 'extracted_tables'
assert extracted_root.exists(), f"No such folder: {extracted_root}"

# Define where to write filtered tables for all reports
filtered_root = REPO_ROOT / '2_output' / 'filtered_tables'
filtered_root.mkdir(exist_ok=True, parents=True)

# %%
# 1) List all extracted reports to get the exact folder name:
available = [d.name for d in extracted_root.iterdir() if d.is_dir()]
print("Available reports:", available)

# 2) Specify the report folder name under 'extracted_tables'
#    Must exactly match one of the names printed above
report_name = '01UK_total_HR'

# 3) Build the input and output paths for that report
input_dir  = extracted_root / report_name
assert input_dir.exists(), f"No such folder: {input_dir}"
output_dir = filtered_root  / report_name

# 4) Run Stage2B non‑interactively on that one report
run(input_dir, output_dir, threshold=10.0)
print(f"✅ {report_name} → {output_dir.resolve()}")
# Out:
# Available reports: ['Volkswagen', 'RFA_ELO_2024_EN-1', 'Commerzbank_Group_Annual_Report_2024', 'cez-group-annual-financial-report-2024', 'upm-annual-report-2024', 'Carlsberg Group_2024 Annual Report', 'brenntag_annual-report-2024_en', 'Amorim_RC24_EN', 'Cenergy-Annual_Report_2024', 'Annual-Report-HoldCo-2024-Web', 'AB InBev 2024 Annual Report FINAL_Interactive', 'DHL-Group-2024-Annual-Report', 'annual-report-2024-data', 'Orsted Annual Report 2024', 'annual-report-2024-equinor-compressed', '01UK_total_HR', '24-VUB-Vyrocna-sprava-ENG', 'consolidated-annual-report-endesa-2024', 'sopra_steria_urd_2024_en_opti', 'ferrovial-integrated-annual-report-2024-1', 'ad_annual-report_2024_interactive', 'f3bb40f8-e502-409f-b3b3-a61e2954531b', 'adidas-ar24', '2024 ING Groep NV annual report', '2025-04-23-Eramet-URD-2024-EN', 'EXOR 2024 Annual Report', 'Wolters_Kluwer_2024_Annual_Report', 'FiskarsGroup_Annual_Report_2024', 'eri_euroapi2024_urd_en_basse-definition_31march_19h28', 'Evonik_Financial_and_Sustainability_Report_2024', 'EUR_URD2024_MEL_', 'allianz-group-annual-report-2024', 'Brunel-Annual-Report-2024-pdf', 'Informe_de_Gestion_Consolidado_2024_ENG', 'Basic-Fit Annual_Report_2024_Webversion', 'CNP-Assurances-SA-and-subsidiaries-2024-URD', '6-2024-KPN-Integrated-Annual-Report', 'WithSecure_Annual_Report_2024', 'management-board-report-on-cd-projekt-group-activities-in-2024', 'cfreport - besi-annual-report-2024', 'TomTom_Annual Report 2024 (PDF Version)', 'airbus_report_of_the_board_of_directors_2024', 'Bureau-Veritas_Universal_Registration_Document_2024_16.3_Mo', 'vattenfall-annual-and-sustainability-report-2024', 'entire-full-report-basf-ar24', 'Valeo_2024-Universal-registration-document', 'Austrian Post Annual Report 2024', 'FLS-annual-report-2024', 'CLARIANE_DEU_2024_UK', 'vinci-2024-universal-registration-document', 'verbund-integrated-annual-report-2024-englisch-final-1', '2024 Adyen Annual Report', 'Zabka-Group-2024-AR-Full-year', 'annual_report_2024_bnp_paribas_fortis_en', 'f849b5ab-5209-4719-81e9-bdfcc9103670', 'finnair-financial-information-2024', 'GB24-gesamt-EN_final', 'AR2024_FINAL_en', 'Corbion_annual_report_2024', 'Randstad_Annual_Report_2024_0', 'bayer-annual-report-2024', '2024-Acerinox-Group-Consolidated-Management-Report', 'management_board_report_on_activity_of_enea_and_enea_group', 'Consolidated_Financial_Statements_2024_including_Consolidated_Sustainability_Report', 'Elisa_AnnualReport_2024', 'Covestro_2024_GB_EN', 'FMO Annual Report 2024_complete_LR', 'Stellantis-NV-20241231-Annual-Report', 'Borealis-Group-Annual-Report-2024-EN', 'ABN_AMRO___Integrated_Annual_Report_2024', 'Annual-Report-2024-Enagas', '41bba0a0-6f60-485f-9141-a50ef8acee26', 'Annual Report 2024 - for print', 'UniCredit', 'Capgemini_-_2025-03-21_-_2024_Universal_Registration_Document', 'fingrid_oyj_annual_report_2024', 'Terna_2024_Annual_Report_8dd871205a435e0', 'bn_annual_report_2024', 'cchbc-iar-2024.pdf.downloadasset', 'BMW-Group-Report-2024-en', 'bilancio integrato-20250404-ENG (2)', 'entire-merck-ar24', 'CH_2024 Annual Report', 'FA_0124_Geschaeftsbericht_EN_RZ_250325_FINAL', '2024 Financial Report_Volume1_Management, Sustainability and Governance_internet', 'Annual Report 2024_Zalando SE_EN_250503_s', '2.2 BoD Report 2024 EN -14.03.2025_FINAL', 'f-secure-annual-report-2024', 'f5937bce-c119-4d4d-91fd-9306c8d2c744', 'Veolia_2024_URD', '2025-03-20-rwe-annual-report-2024', '2024 FBD HOLDINGS ANNUAL REPORT 2024-compressed', 'f10e19e9-3289-43e1-85cc-5449908cf864', 'ESSILORLUXOTTICA_URD-US-2024_MEL', 'Etteplan', 'Vestas Annual Report 2024', 'PhilipsFullAnnualReport2024-English', 'cargotec-annual-report-2024-en', 'fy-2024-download-sag-annual-report-en-data', 'OMV Combined Annual Report 2024']
# Page 121: saved page_121_tbl02_Camelot-Stream_conf97.csv, score=273.18
# Page 122: saved page_122_tbl01_Camelot-Stream_conf77.csv, score=105.45
# ✅ 01UK_total_HR → /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/01UK_total_HR

# %%
#OPTIONALLY
#run through all pdfs in excel file

# %%
#Load all report names from Excel
excel_path = REPO_ROOT / "0_data" / "table_extraction_accuracy2.xlsx"
sheet_name = "suggested weights"
pdf_df = pd.read_excel(excel_path, sheet_name=sheet_name)
pdf_names = pdf_df["pdf_path"].dropna().apply(lambda p: Path(p).stem).unique()

# %%
for report_name in pdf_names:
    input_dir  = extracted_root / report_name
    output_dir = filtered_root  / report_name

    if not input_dir.exists():
        print(f"⚠️ Skipping {report_name}: no extracted tables found.")
        continue

    try:
        print(f"\n🔍 Running Stage2B for: {report_name}")
        run(input_dir, output_dir, threshold=10.0)
        print(f"✅ Saved filtered tables to: {output_dir}")
    except Exception as e:
        print(f"❌ Failed on {report_name}: {e}")
# Out:
# 🔍 Running Stage2B for: 01UK_total_HR
# Page 121: saved page_121_tbl02_Camelot-Stream_conf97.csv, score=273.18
# Page 122: saved page_122_tbl01_Camelot-Stream_conf77.csv, score=105.45
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/01UK_total_HR
#
# 🔍 Running Stage2B for: 2.2 BoD Report 2024 EN -14.03.2025_FINAL
# Page 201: saved page_201_tbl01_Camelot-Stream_conf73.csv, score=29.84
# Page 202: saved page_202_tbl01_Camelot-Stream_conf71.csv, score=39.86
# Page 203: saved page_203_tbl01_Camelot-Lattice_conf99.csv, score=17.11
# Page 207: saved page_207_tbl01_Camelot-Stream_conf58.csv, score=7.71
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/2.2 BoD Report 2024 EN -14.03.2025_FINAL
#
# 🔍 Running Stage2B for: 2024 Adyen Annual Report
# Page 111: saved page_111_tbl01_Camelot-Stream_conf58.csv, score=15.90
# Page 112: saved page_112_tbl01_Camelot-Stream_conf42.csv, score=24.78
# Page 113: saved page_113_tbl01_Camelot-Stream_conf70.csv, score=45.30
# Page 114: saved page_114_tbl01_Camelot-Stream_conf76.csv, score=26.77
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/2024 Adyen Annual Report
#
# 🔍 Running Stage2B for: 2024 FBD HOLDINGS ANNUAL REPORT 2024-compressed
# Page 169: saved page_169_tbl02_Camelot-Stream_conf69.csv, score=16.36
# Page 170: saved page_170_tbl03_Camelot-Stream_conf65.csv, score=44.89
# Page 171: saved page_171_tbl02_Camelot-Stream_conf66.csv, score=33.38
# Page 172: saved page_172_tbl01_Camelot-Stream_conf69.csv, score=15.15
# Page 174: saved page_174_tbl01_Camelot-Stream_conf72.csv, score=37.69
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/2024 FBD HOLDINGS ANNUAL REPORT 2024-compressed
#
# 🔍 Running Stage2B for: 2024 Financial Report_Volume1_Management, Sustainability and Governance_internet
# Page 224: saved page_224_tbl02_Camelot-Stream_conf26.csv, score=28.11
# Page 225: saved page_225_tbl05_Camelot-Stream_conf34.csv, score=20.33
# Page 226: saved page_226_tbl02_Camelot-Stream_conf52.csv, score=22.60
# Page 227: saved page_227_tbl02_Camelot-Stream_conf46.csv, score=25.62
# Page 228: saved page_228_tbl02_Camelot-Stream_conf59.csv, score=27.63
# Page 229: saved page_229_tbl02_Camelot-Stream_conf41.csv, score=19.61
# Page 230: saved page_230_tbl02_Camelot-Stream_conf39.csv, score=28.55
# Page 232: saved page_232_tbl01_Camelot-Stream_conf44.csv, score=8.30
# Page 233: saved page_233_tbl01_Camelot-Stream_conf57.csv, score=29.31
# Page 234: saved page_234_tbl01_Camelot-Stream_conf58.csv, score=22.82
# Page 235: saved page_235_tbl01_Camelot-Stream_conf52.csv, score=12.82
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/2024 Financial Report_Volume1_Management, Sustainability and Governance_internet
#
# 🔍 Running Stage2B for: 2024 ING Groep NV annual report
# Page 360: saved page_360_tbl02_Camelot-Stream_conf48.csv, score=8.76
# Page 362: saved page_362_tbl01_Camelot-Lattice_conf43.csv, score=25.83
# Page 363: saved page_363_tbl02_Camelot-Stream_conf51.csv, score=49.82
# Page 364: saved page_364_tbl01_Camelot-Lattice_conf51.csv, score=49.80
# Page 365: saved page_365_tbl01_Camelot-Lattice_conf52.csv, score=24.17
# Page 366: saved page_366_tbl01_Camelot-Lattice_conf66.csv, score=23.06
# Page 367: saved page_367_tbl01_Camelot-Stream_conf81.csv, score=22.88
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/2024 ING Groep NV annual report
#
# 🔍 Running Stage2B for: 2024-Acerinox-Group-Consolidated-Management-Report
# Page 167: saved page_167_tbl01_Camelot-Stream_conf52.csv, score=11.40
# Page 168: saved page_168_tbl01_Camelot-Stream_conf56.csv, score=-3.83
# Page 169: saved page_169_tbl02_Camelot-Stream_conf65.csv, score=45.32
# Page 170: saved page_170_tbl01_Camelot-Stream_conf95.csv, score=64.91
# Page 171: saved page_171_tbl01_Camelot-Stream_conf95.csv, score=48.28
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/2024-Acerinox-Group-Consolidated-Management-Report
#
# 🔍 Running Stage2B for: 2025-03-20-rwe-annual-report-2024
# Page 178: saved page_178_tbl01_Camelot-Stream_conf71.csv, score=50.69
# Page 179: saved page_179_tbl01_Camelot-Stream_conf65.csv, score=33.66
# Page 180: saved page_180_tbl01_Camelot-Stream_conf60.csv, score=26.12
# Page 181: saved page_181_tbl01_Camelot-Stream_conf58.csv, score=23.11
# Page 182: saved page_182_tbl01_Camelot-Stream_conf69.csv, score=42.73
# Page 183: saved page_183_tbl01_Camelot-Stream_conf58.csv, score=24.61
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/2025-03-20-rwe-annual-report-2024
#
# 🔍 Running Stage2B for: 2025-04-23-Eramet-URD-2024-EN
# Page 557: saved page_557_tbl02_Camelot-Stream_conf52.csv, score=19.15
# Page 558: saved page_558_tbl01_Camelot-Stream_conf61.csv, score=157.44
# Page 559: saved page_559_tbl01_Camelot-Stream_conf51.csv, score=129.87
# Page 560: saved page_560_tbl01_Camelot-Stream_conf64.csv, score=106.40
# Page 561: saved page_561_tbl01_Camelot-Stream_conf57.csv, score=143.36
# Page 562: saved page_562_tbl01_Camelot-Stream_conf67.csv, score=152.84
# Page 563: saved page_563_tbl01_Camelot-Stream_conf57.csv, score=153.86
# Page 564: saved page_564_tbl01_Camelot-Stream_conf65.csv, score=56.45
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/2025-04-23-Eramet-URD-2024-EN
#
# 🔍 Running Stage2B for: 24-VUB-Vyrocna-sprava-ENG
# Page 432: saved page_432_tbl01_Camelot-Stream_conf79.csv, score=30.88
# Page 433: saved page_433_tbl01_Camelot-Stream_conf68.csv, score=45.87
# Page 434: saved page_434_tbl01_Camelot-Stream_conf80.csv, score=27.88
# Page 435: saved page_435_tbl01_Camelot-Stream_conf80.csv, score=30.88
# Page 436: saved page_436_tbl01_Camelot-Stream_conf78.csv, score=23.23
# Page 437: saved page_437_tbl01_Camelot-Stream_conf82.csv, score=21.21
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/24-VUB-Vyrocna-sprava-ENG
#
# 🔍 Running Stage2B for: 41bba0a0-6f60-485f-9141-a50ef8acee26
# Page 153: saved page_153_tbl01_Camelot-Stream_conf58.csv, score=32.24
# Page 154: saved page_154_tbl01_Camelot-Stream_conf82.csv, score=31.73
# Page 155: saved page_155_tbl01_Camelot-Stream_conf86.csv, score=42.31
# Page 156: saved page_156_tbl01_Camelot-Stream_conf77.csv, score=25.70
# Page 157: saved page_157_tbl01_Camelot-Stream_conf78.csv, score=10.60
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/41bba0a0-6f60-485f-9141-a50ef8acee26
#
# 🔍 Running Stage2B for: 6-2024-KPN-Integrated-Annual-Report
# Page 69: saved page_069_tbl01_Camelot-Stream_conf94.csv, score=115.82
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/6-2024-KPN-Integrated-Annual-Report
#
# 🔍 Running Stage2B for: AB InBev 2024 Annual Report FINAL_Interactive
# No tables passed the filters.
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/AB InBev 2024 Annual Report FINAL_Interactive
#
# 🔍 Running Stage2B for: ABN_AMRO___Integrated_Annual_Report_2024
# Page 223: saved page_223_tbl02_Camelot-Stream_conf74.csv, score=82.57
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/ABN_AMRO___Integrated_Annual_Report_2024
#
# 🔍 Running Stage2B for: ad_annual-report_2024_interactive
# Page 366: saved page_366_tbl01_Camelot-Stream_conf58.csv, score=10.79
# Page 367: saved page_367_tbl01_Camelot-Stream_conf55.csv, score=64.27
# Page 368: saved page_368_tbl01_Camelot-Stream_conf50.csv, score=84.31
# Page 369: saved page_369_tbl01_Camelot-Stream_conf48.csv, score=48.28
# Page 370: saved page_370_tbl01_Camelot-Stream_conf44.csv, score=49.27
# Page 371: saved page_371_tbl01_Camelot-Stream_conf42.csv, score=40.28
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/ad_annual-report_2024_interactive
#
# 🔍 Running Stage2B for: adidas-ar24
# Page 143: saved page_143_tbl01_Camelot-Stream_conf90.csv, score=81.95
# Page 144: saved page_144_tbl01_Camelot-Stream_conf91.csv, score=78.93
# Page 145: saved page_145_tbl01_Camelot-Stream_conf85.csv, score=41.23
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/adidas-ar24
#
# 🔍 Running Stage2B for: airbus_report_of_the_board_of_directors_2024
# Page 150: saved page_150_tbl02_Camelot-Stream_conf60.csv, score=31.52
# Page 151: saved page_151_tbl01_Camelot-Stream_conf57.csv, score=10.12
# Page 152: saved page_152_tbl02_Camelot-Stream_conf70.csv, score=50.82
# Page 153: saved page_153_tbl01_Camelot-Stream_conf55.csv, score=101.88
# Page 154: saved page_154_tbl01_Camelot-Stream_conf81.csv, score=83.86
# Page 155: saved page_155_tbl01_Camelot-Stream_conf81.csv, score=83.87
# Page 156: saved page_156_tbl01_Camelot-Stream_conf86.csv, score=74.87
# Page 157: saved page_157_tbl02_Camelot-Stream_conf57.csv, score=26.34
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/airbus_report_of_the_board_of_directors_2024
#
# 🔍 Running Stage2B for: allianz-group-annual-report-2024
# Page 157: saved page_157_tbl01_Camelot-Stream_conf73.csv, score=163.90
# Page 158: saved page_158_tbl01_Camelot-Stream_conf70.csv, score=92.68
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/allianz-group-annual-report-2024
#
# 🔍 Running Stage2B for: Amorim_RC24_EN
# Page 121: saved page_121_tbl01_Camelot-Stream_conf93.csv, score=70.43
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Amorim_RC24_EN
#
# 🔍 Running Stage2B for: Annual Report 2024 - for print
# Page 107: saved page_107_tbl01_Camelot-Stream_conf51.csv, score=56.33
# Page 108: saved page_108_tbl01_Camelot-Stream_conf58.csv, score=63.79
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Annual Report 2024 - for print
#
# 🔍 Running Stage2B for: Annual Report 2024_Zalando SE_EN_250503_s
# Page 285: saved page_285_tbl03_Camelot-Stream_conf93.csv, score=29.24
# Page 286: saved page_286_tbl01_Camelot-Stream_conf70.csv, score=65.90
# Page 287: saved page_287_tbl01_Camelot-Stream_conf65.csv, score=59.90
# Page 288: saved page_288_tbl01_Camelot-Stream_conf65.csv, score=31.21
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Annual Report 2024_Zalando SE_EN_250503_s
#
# 🔍 Running Stage2B for: annual_report_2024_bnp_paribas_fortis_en
# Page 322: saved page_322_tbl02_Camelot-Stream_conf76.csv, score=43.35
# Page 323: saved page_323_tbl01_Camelot-Stream_conf71.csv, score=55.32
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/annual_report_2024_bnp_paribas_fortis_en
#
# 🔍 Running Stage2B for: annual-report-2024-data
# Page 214: saved page_214_tbl01_Camelot-Stream_conf81.csv, score=14.77
# Page 215: saved page_215_tbl01_Camelot-Stream_conf88.csv, score=88.31
# Page 216: saved page_216_tbl01_Camelot-Stream_conf95.csv, score=65.79
# Page 217: saved page_217_tbl01_Camelot-Stream_conf88.csv, score=64.24
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/annual-report-2024-data
#
# 🔍 Running Stage2B for: Annual-Report-2024-Enagas
# No tables passed the filters.
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Annual-Report-2024-Enagas
#
# 🔍 Running Stage2B for: annual-report-2024-equinor-compressed
# Page 182: saved page_182_tbl01_Camelot-Stream_conf48.csv, score=64.83
# Page 183: saved page_183_tbl01_Camelot-Stream_conf52.csv, score=79.84
# Page 184: saved page_184_tbl01_Camelot-Stream_conf23.csv, score=5.36
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/annual-report-2024-equinor-compressed
#
# 🔍 Running Stage2B for: Annual-Report-HoldCo-2024-Web
# Page 35: saved page_035_tbl01_Camelot-Lattice_conf98.csv, score=-0.39
# Page 39: saved page_039_tbl02_Camelot-Stream_conf97.csv, score=189.83
# Page 40: saved page_040_tbl03_Camelot-Stream_conf92.csv, score=58.13
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Annual-Report-HoldCo-2024-Web
#
# 🔍 Running Stage2B for: AR2024_FINAL_en
# Page 120: saved page_120_tbl01_Camelot-Stream_conf90.csv, score=91.05
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/AR2024_FINAL_en
#
# 🔍 Running Stage2B for: Austrian Post Annual Report 2024
# Page 52: saved page_052_tbl01_Camelot-Stream_conf40.csv, score=41.82
# Page 53: saved page_053_tbl01_Camelot-Stream_conf55.csv, score=55.48
# Page 54: saved page_054_tbl02_Camelot-Stream_conf43.csv, score=40.84
# Page 55: saved page_055_tbl01_Camelot-Stream_conf95.csv, score=13.46
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Austrian Post Annual Report 2024
#
# 🔍 Running Stage2B for: Basic-Fit Annual_Report_2024_Webversion
# Page 74: saved page_074_tbl01_Camelot-Stream_conf63.csv, score=63.82
# Page 75: saved page_075_tbl01_Camelot-Stream_conf65.csv, score=47.82
# Page 77: saved page_077_tbl01_Camelot-Stream_conf99.csv, score=47.83
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Basic-Fit Annual_Report_2024_Webversion
#
# 🔍 Running Stage2B for: bayer-annual-report-2024
# Page 233: saved page_233_tbl01_Camelot-Stream_conf74.csv, score=93.39
# Page 234: saved page_234_tbl01_Camelot-Stream_conf87.csv, score=117.34
# Page 235: saved page_235_tbl01_Camelot-Stream_conf79.csv, score=91.83
# Page 236: saved page_236_tbl01_Camelot-Stream_conf82.csv, score=102.35
# Page 237: saved page_237_tbl01_Camelot-Stream_conf81.csv, score=85.81
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/bayer-annual-report-2024
#
# 🔍 Running Stage2B for: bilancio integrato-20250404-ENG (2)
# Page 192: saved page_192_tbl02_Camelot-Stream_conf80.csv, score=113.44
# Page 193: saved page_193_tbl01_Camelot-Stream_conf79.csv, score=162.45
# Page 194: saved page_194_tbl01_Camelot-Stream_conf78.csv, score=141.46
# Page 195: saved page_195_tbl01_Camelot-Stream_conf80.csv, score=173.49
# Page 196: saved page_196_tbl01_Camelot-Stream_conf74.csv, score=33.25
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/bilancio integrato-20250404-ENG (2)
#
# 🔍 Running Stage2B for: BMW-Group-Report-2024-en
# Page 229: saved page_229_tbl01_Camelot-Stream_conf68.csv, score=17.76
# Page 230: saved page_230_tbl01_Camelot-Stream_conf55.csv, score=7.25
# Page 231: saved page_231_tbl01_Camelot-Stream_conf62.csv, score=11.76
# Page 232: saved page_232_tbl01_Camelot-Stream_conf71.csv, score=13.23
# Page 233: saved page_233_tbl01_Camelot-Stream_conf53.csv, score=1.18
# Page 234: saved page_234_tbl01_Camelot-Stream_conf52.csv, score=44.19
# Page 237: saved page_237_tbl01_Camelot-Stream_conf48.csv, score=3.33
# Page 238: saved page_238_tbl01_Camelot-Stream_conf77.csv, score=31.32
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/BMW-Group-Report-2024-en
#
# 🔍 Running Stage2B for: bn_annual_report_2024
# Page 104: saved page_104_tbl01_Camelot-Stream_conf56.csv, score=60.29
# Page 105: saved page_105_tbl01_Camelot-Stream_conf65.csv, score=58.75
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/bn_annual_report_2024
#
# 🔍 Running Stage2B for: Borealis-Group-Annual-Report-2024-EN
# No tables passed the filters.
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Borealis-Group-Annual-Report-2024-EN
#
# 🔍 Running Stage2B for: brenntag_annual-report-2024_en
# Page 152: saved page_152_tbl02_Camelot-Stream_conf76.csv, score=16.66
# Page 153: saved page_153_tbl01_Camelot-Stream_conf90.csv, score=56.85
# Page 154: saved page_154_tbl01_Camelot-Stream_conf90.csv, score=47.82
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/brenntag_annual-report-2024_en
#
# 🔍 Running Stage2B for: Brunel-Annual-Report-2024-pdf
# Page 36: saved page_036_tbl02_Camelot-Stream_conf48.csv, score=12.09
# Page 37: saved page_037_tbl01_Camelot-Stream_conf78.csv, score=103.95
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Brunel-Annual-Report-2024-pdf
#
# 🔍 Running Stage2B for: Bureau-Veritas_Universal_Registration_Document_2024_16.3_Mo
# Page 217: saved page_217_tbl01_Camelot-Stream_conf45.csv, score=45.31
# Page 218: saved page_218_tbl01_Camelot-Stream_conf75.csv, score=36.80
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Bureau-Veritas_Universal_Registration_Document_2024_16.3_Mo
#
# 🔍 Running Stage2B for: Capgemini_-_2025-03-21_-_2024_Universal_Registration_Document
# Page 346: saved page_346_tbl01_Camelot-Stream_conf53.csv, score=18.34
# Page 347: saved page_347_tbl01_Camelot-Stream_conf51.csv, score=23.81
# Page 348: saved page_348_tbl01_Camelot-Stream_conf52.csv, score=29.86
# Page 349: saved page_349_tbl01_Camelot-Stream_conf50.csv, score=36.35
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Capgemini_-_2025-03-21_-_2024_Universal_Registration_Document
#
# 🔍 Running Stage2B for: cargotec-annual-report-2024-en
# No tables passed the filters.
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/cargotec-annual-report-2024-en
#
# 🔍 Running Stage2B for: Carlsberg Group_2024 Annual Report
# Page 53: saved page_053_tbl02_Camelot-Stream_conf73.csv, score=9.18
# Page 54: saved page_054_tbl01_Camelot-Stream_conf83.csv, score=80.38
# Page 55: saved page_055_tbl01_Camelot-Stream_conf85.csv, score=92.39
# Page 56: saved page_056_tbl01_Camelot-Stream_conf85.csv, score=14.88
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Carlsberg Group_2024 Annual Report
#
# 🔍 Running Stage2B for: cchbc-iar-2024.pdf.downloadasset
# Page 66: saved page_066_tbl01_Camelot-Stream_conf91.csv, score=12.45
# Page 67: saved page_067_tbl01_Camelot-Stream_conf78.csv, score=36.82
# Page 68: saved page_068_tbl01_Camelot-Stream_conf81.csv, score=54.31
# Page 69: saved page_069_tbl01_Camelot-Stream_conf84.csv, score=66.28
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/cchbc-iar-2024.pdf.downloadasset
#
# 🔍 Running Stage2B for: Cenergy-Annual_Report_2024
# Page 140: saved page_140_tbl01_Camelot-Lattice_conf86.csv, score=17.65
# Page 141: saved page_141_tbl04_Camelot-Stream_conf75.csv, score=17.62
# Page 142: saved page_142_tbl03_Camelot-Stream_conf65.csv, score=23.73
# Page 143: saved page_143_tbl03_Camelot-Stream_conf59.csv, score=22.85
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Cenergy-Annual_Report_2024
#
# 🔍 Running Stage2B for: cez-group-annual-financial-report-2024
# No tables passed the filters.
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/cez-group-annual-financial-report-2024
#
# 🔍 Running Stage2B for: cfreport - besi-annual-report-2024
# No tables passed the filters.
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/cfreport - besi-annual-report-2024
#
# 🔍 Running Stage2B for: CH_2024 Annual Report
# Page 192: saved page_192_tbl03_Camelot-Stream_conf43.csv, score=24.92
# Page 193: saved page_193_tbl02_Camelot-Stream_conf61.csv, score=49.51
# Page 194: saved page_194_tbl02_Camelot-Stream_conf54.csv, score=19.54
# Page 195: saved page_195_tbl02_Camelot-Stream_conf56.csv, score=36.02
# Page 196: saved page_196_tbl02_Camelot-Stream_conf47.csv, score=30.04
# Page 197: saved page_197_tbl04_Camelot-Stream_conf72.csv, score=19.71
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/CH_2024 Annual Report
#
# 🔍 Running Stage2B for: CLARIANE_DEU_2024_UK
# Page 63: saved page_063_tbl01_Camelot-Stream_conf77.csv, score=110.96
# Page 64: saved page_064_tbl01_Camelot-Stream_conf67.csv, score=58.24
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/CLARIANE_DEU_2024_UK
#
# 🔍 Running Stage2B for: CNP-Assurances-SA-and-subsidiaries-2024-URD
# Page 184: saved page_184_tbl03_Camelot-Stream_conf70.csv, score=41.79
# Page 185: saved page_185_tbl02_Camelot-Stream_conf67.csv, score=42.81
# Page 186: saved page_186_tbl03_Camelot-Stream_conf67.csv, score=33.34
# Page 187: saved page_187_tbl02_Camelot-Stream_conf63.csv, score=45.82
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/CNP-Assurances-SA-and-subsidiaries-2024-URD
#
# 🔍 Running Stage2B for: Commerzbank_Group_Annual_Report_2024
# Page 81: saved page_081_tbl02_Camelot-Stream_conf88.csv, score=12.94
# Page 82: saved page_082_tbl01_Camelot-Stream_conf87.csv, score=16.01
# Page 83: saved page_083_tbl02_Camelot-Stream_conf87.csv, score=28.31
# Page 84: saved page_084_tbl01_Camelot-Stream_conf75.csv, score=17.34
# Page 85: saved page_085_tbl02_Camelot-Stream_conf65.csv, score=66.31
# Page 86: saved page_086_tbl01_Camelot-Stream_conf58.csv, score=41.37
# Page 87: saved page_087_tbl03_Camelot-Stream_conf46.csv, score=7.86
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Commerzbank_Group_Annual_Report_2024
#
# 🔍 Running Stage2B for: Consolidated_Financial_Statements_2024_including_Consolidated_Sustainability_Report
# No tables passed the filters.
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Consolidated_Financial_Statements_2024_including_Consolidated_Sustainability_Report
#
# 🔍 Running Stage2B for: consolidated-annual-report-endesa-2024
# Page 162: saved page_162_tbl01_Camelot-Stream_conf89.csv, score=15.65
# Page 163: saved page_163_tbl02_Camelot-Stream_conf65.csv, score=23.76
# Page 164: saved page_164_tbl01_Camelot-Stream_conf97.csv, score=120.40
# Page 165: saved page_165_tbl01_Camelot-Stream_conf72.csv, score=110.93
# Page 166: saved page_166_tbl01_Camelot-Stream_conf68.csv, score=84.31
# Page 167: saved page_167_tbl01_Camelot-Stream_conf83.csv, score=171.04
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/consolidated-annual-report-endesa-2024
#
# 🔍 Running Stage2B for: Corbion_annual_report_2024
# Page 126: saved page_126_tbl01_Camelot-Stream_conf57.csv, score=24.26
# Page 127: saved page_127_tbl01_Camelot-Stream_conf56.csv, score=34.34
# Page 128: saved page_128_tbl01_Camelot-Stream_conf59.csv, score=37.35
# Page 129: saved page_129_tbl01_Camelot-Stream_conf57.csv, score=25.34
# Page 130: saved page_130_tbl01_Camelot-Stream_conf50.csv, score=13.21
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Corbion_annual_report_2024
#
# 🔍 Running Stage2B for: Covestro_2024_GB_EN
# Page 137: saved page_137_tbl01_Camelot-Stream_conf47.csv, score=4.24
# Page 138: saved page_138_tbl01_Camelot-Stream_conf62.csv, score=56.31
# Page 139: saved page_139_tbl01_Camelot-Stream_conf68.csv, score=89.81
# Page 140: saved page_140_tbl01_Camelot-Stream_conf58.csv, score=91.31
# Page 141: saved page_141_tbl01_Camelot-Stream_conf52.csv, score=21.64
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Covestro_2024_GB_EN
#
# 🔍 Running Stage2B for: DHL-Group-2024-Annual-Report
# Page 117: saved page_117_tbl01_Camelot-Stream_conf79.csv, score=30.24
# Page 118: saved page_118_tbl01_Camelot-Stream_conf96.csv, score=45.78
# Page 119: saved page_119_tbl01_Camelot-Stream_conf92.csv, score=33.75
# Page 121: saved page_121_tbl01_Camelot-Stream_conf95.csv, score=41.29
# Page 122: saved page_122_tbl01_Camelot-Stream_conf100.csv, score=14.09
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/DHL-Group-2024-Annual-Report
#
# 🔍 Running Stage2B for: Elisa_AnnualReport_2024
# Page 100: saved page_100_tbl01_Camelot-Stream_conf51.csv, score=25.76
# Page 101: saved page_101_tbl01_Camelot-Stream_conf52.csv, score=51.31
# Page 102: saved page_102_tbl01_Camelot-Stream_conf54.csv, score=27.19
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Elisa_AnnualReport_2024
#
# 🔍 Running Stage2B for: entire-full-report-basf-ar24
# Page 147: saved page_147_tbl02_Camelot-Stream_conf87.csv, score=54.86
# Page 148: saved page_148_tbl01_Camelot-Stream_conf66.csv, score=67.96
# Page 149: saved page_149_tbl01_Camelot-Stream_conf68.csv, score=11.11
# Page 150: saved page_150_tbl01_Camelot-Stream_conf-40.csv, score=22.47
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/entire-full-report-basf-ar24
#
# 🔍 Running Stage2B for: entire-merck-ar24
# No tables passed the filters.
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/entire-merck-ar24
#
# 🔍 Running Stage2B for: eri_euroapi2024_urd_en_basse-definition_31march_19h28
# Page 340: saved page_340_tbl01_Camelot-Stream_conf75.csv, score=116.38
# Page 341: saved page_341_tbl01_Camelot-Stream_conf74.csv, score=95.37
# Page 342: saved page_342_tbl01_Camelot-Stream_conf79.csv, score=60.23
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/eri_euroapi2024_urd_en_basse-definition_31march_19h28
#
# 🔍 Running Stage2B for: ESSILORLUXOTTICA_URD-US-2024_MEL
# Page 359: saved page_359_tbl02_Camelot-Stream_conf45.csv, score=37.89
# Page 362: saved page_362_tbl01_Camelot-Stream_conf44.csv, score=38.89
# Page 363: saved page_363_tbl01_Camelot-Stream_conf40.csv, score=38.36
# Page 364: saved page_364_tbl01_Camelot-Stream_conf43.csv, score=57.07
# Page 365: saved page_365_tbl01_Camelot-Stream_conf36.csv, score=26.34
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/ESSILORLUXOTTICA_URD-US-2024_MEL
#
# 🔍 Running Stage2B for: Etteplan
# Page 108: saved page_108_tbl01_Camelot-Stream_conf54.csv, score=35.70
# Page 109: saved page_109_tbl01_Camelot-Stream_conf61.csv, score=56.69
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Etteplan
#
# 🔍 Running Stage2B for: EUR_URD2024_MEL_
# Page 131: saved page_131_tbl04_Camelot-Stream_conf82.csv, score=54.39
# Page 132: saved page_132_tbl06_Camelot-Stream_conf57.csv, score=33.01
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/EUR_URD2024_MEL_
#
# 🔍 Running Stage2B for: Evonik_Financial_and_Sustainability_Report_2024
# Page 212: saved page_212_tbl01_Camelot-Stream_conf52.csv, score=53.41
# Page 213: saved page_213_tbl01_Camelot-Stream_conf45.csv, score=48.88
# Page 214: saved page_214_tbl01_Camelot-Stream_conf54.csv, score=42.80
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Evonik_Financial_and_Sustainability_Report_2024
#
# 🔍 Running Stage2B for: EXOR 2024 Annual Report
# Page 154: saved page_154_tbl02_Camelot-Stream_conf77.csv, score=36.86
# Page 155: saved page_155_tbl02_Camelot-Stream_conf77.csv, score=30.88
# Page 156: saved page_156_tbl03_Camelot-Stream_conf80.csv, score=11.10
# Page 157: saved page_157_tbl02_Camelot-Stream_conf51.csv, score=3.68
# Page 158: saved page_158_tbl02_Camelot-Stream_conf78.csv, score=19.63
# Page 159: saved page_159_tbl02_Camelot-Stream_conf63.csv, score=12.19
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/EXOR 2024 Annual Report
#
# 🔍 Running Stage2B for: f-secure-annual-report-2024
# Page 61: saved page_061_tbl01_Camelot-Stream_conf90.csv, score=8.76
# Page 62: saved page_062_tbl01_Camelot-Stream_conf66.csv, score=46.86
# Page 63: saved page_063_tbl01_Camelot-Stream_conf75.csv, score=23.17
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/f-secure-annual-report-2024
#
# 🔍 Running Stage2B for: f10e19e9-3289-43e1-85cc-5449908cf864
# Page 157: saved page_157_tbl01_Camelot-Stream_conf54.csv, score=71.97
# Page 158: saved page_158_tbl01_Camelot-Stream_conf72.csv, score=40.93
# Page 159: saved page_159_tbl01_Camelot-Stream_conf41.csv, score=31.41
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/f10e19e9-3289-43e1-85cc-5449908cf864
#
# 🔍 Running Stage2B for: f3bb40f8-e502-409f-b3b3-a61e2954531b
# Page 371: saved page_371_tbl01_Camelot-Stream_conf51.csv, score=19.32
# Page 372: saved page_372_tbl01_Camelot-Stream_conf53.csv, score=24.84
# Page 373: saved page_373_tbl01_Camelot-Stream_conf53.csv, score=21.85
# Page 374: saved page_374_tbl01_Camelot-Stream_conf43.csv, score=17.34
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/f3bb40f8-e502-409f-b3b3-a61e2954531b
#
# 🔍 Running Stage2B for: f5937bce-c119-4d4d-91fd-9306c8d2c744
# Page 95: saved page_095_tbl01_Camelot-Stream_conf78.csv, score=20.18
# Page 96: saved page_096_tbl01_Camelot-Stream_conf83.csv, score=62.23
# Page 97: saved page_097_tbl01_Camelot-Stream_conf79.csv, score=18.59
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/f5937bce-c119-4d4d-91fd-9306c8d2c744
#
# 🔍 Running Stage2B for: f849b5ab-5209-4719-81e9-bdfcc9103670
# No tables passed the filters.
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/f849b5ab-5209-4719-81e9-bdfcc9103670
#
# 🔍 Running Stage2B for: FA_0124_Geschaeftsbericht_EN_RZ_250325_FINAL
# Page 27: saved page_027_tbl02_Camelot-Stream_conf51.csv, score=5.23
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/FA_0124_Geschaeftsbericht_EN_RZ_250325_FINAL
#
# 🔍 Running Stage2B for: ferrovial-integrated-annual-report-2024-1
# Page 68: saved page_068_tbl02_Camelot-Stream_conf74.csv, score=158.53
# Page 69: saved page_069_tbl01_Camelot-Stream_conf54.csv, score=176.63
# Page 70: saved page_070_tbl01_Camelot-Stream_conf98.csv, score=159.94
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/ferrovial-integrated-annual-report-2024-1
#
# 🔍 Running Stage2B for: fingrid_oyj_annual_report_2024
# Page 81: saved page_081_tbl01_Camelot-Stream_conf49.csv, score=33.63
# Page 82: saved page_082_tbl01_Camelot-Stream_conf37.csv, score=20.72
# Page 83: saved page_083_tbl01_Camelot-Stream_conf39.csv, score=82.42
# Page 84: saved page_084_tbl01_Camelot-Stream_conf60.csv, score=61.22
# Page 85: saved page_085_tbl01_Camelot-Stream_conf63.csv, score=29.60
# Page 86: saved page_086_tbl01_Camelot-Stream_conf56.csv, score=59.76
# Page 87: saved page_087_tbl01_Camelot-Stream_conf48.csv, score=37.18
# Page 88: saved page_088_tbl01_Camelot-Stream_conf52.csv, score=52.24
# Page 89: saved page_089_tbl01_Camelot-Stream_conf46.csv, score=40.21
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/fingrid_oyj_annual_report_2024
#
# 🔍 Running Stage2B for: finnair-financial-information-2024
# Page 61: saved page_061_tbl01_Camelot-Stream_conf61.csv, score=12.45
# Page 62: saved page_062_tbl01_Camelot-Stream_conf58.csv, score=99.39
# Page 63: saved page_063_tbl01_Camelot-Stream_conf78.csv, score=104.92
# Page 64: saved page_064_tbl01_Camelot-Stream_conf55.csv, score=112.41
# Page 65: saved page_065_tbl01_Camelot-Stream_conf57.csv, score=116.91
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/finnair-financial-information-2024
#
# 🔍 Running Stage2B for: FiskarsGroup_Annual_Report_2024
# Page 27: saved page_027_tbl01_Camelot-Stream_conf18.csv, score=13.09
# Page 28: saved page_028_tbl01_Camelot-Stream_conf61.csv, score=67.21
# Page 29: saved page_029_tbl01_Camelot-Stream_conf53.csv, score=74.75
# Page 30: saved page_030_tbl01_Camelot-Stream_conf60.csv, score=53.71
# Page 31: saved page_031_tbl01_Camelot-Stream_conf68.csv, score=34.15
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/FiskarsGroup_Annual_Report_2024
#
# 🔍 Running Stage2B for: FLS-annual-report-2024
# Page 76: saved page_076_tbl01_Camelot-Stream_conf60.csv, score=39.72
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/FLS-annual-report-2024
#
# 🔍 Running Stage2B for: FMO Annual Report 2024_complete_LR
# Page 223: saved page_223_tbl02_Camelot-Stream_conf47.csv, score=77.76
# Page 224: saved page_224_tbl02_Camelot-Stream_conf59.csv, score=106.36
# Page 226: saved page_226_tbl02_Camelot-Stream_conf73.csv, score=78.36
# Page 227: saved page_227_tbl02_Camelot-Stream_conf86.csv, score=10.55
# Page 228: saved page_228_tbl01_Camelot-Stream_conf52.csv, score=32.80
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/FMO Annual Report 2024_complete_LR
#
# 🔍 Running Stage2B for: fy-2024-download-sag-annual-report-en-data
# Page 136: saved page_136_tbl01_Camelot-Stream_conf-12.csv, score=22.41
# Page 137: saved page_137_tbl01_Camelot-Stream_conf-9.csv, score=7.34
# Page 138: saved page_138_tbl01_Camelot-Stream_conf37.csv, score=21.25
# Page 139: saved page_139_tbl01_Camelot-Stream_conf40.csv, score=28.81
# Page 140: saved page_140_tbl01_Camelot-Stream_conf39.csv, score=37.91
# Page 141: saved page_141_tbl01_Camelot-Stream_conf42.csv, score=36.38
# Page 142: saved page_142_tbl01_Camelot-Stream_conf38.csv, score=33.40
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/fy-2024-download-sag-annual-report-en-data
#
# 🔍 Running Stage2B for: GB24-gesamt-EN_final
# No tables passed the filters.
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/GB24-gesamt-EN_final
#
# 🔍 Running Stage2B for: Informe_de_Gestion_Consolidado_2024_ENG
# Page 586: saved page_586_tbl02_Camelot-Stream_conf69.csv, score=18.23
# Page 587: saved page_587_tbl01_Camelot-Stream_conf47.csv, score=44.80
# Page 588: saved page_588_tbl01_Camelot-Stream_conf61.csv, score=25.31
# Page 589: saved page_589_tbl01_Camelot-Stream_conf63.csv, score=26.74
# Page 590: saved page_590_tbl01_Camelot-Stream_conf55.csv, score=35.73
# Page 591: saved page_591_tbl01_Camelot-Stream_conf57.csv, score=44.75
# Page 592: saved page_592_tbl01_Camelot-Stream_conf59.csv, score=32.78
# Page 593: saved page_593_tbl01_Camelot-Stream_conf54.csv, score=22.14
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Informe_de_Gestion_Consolidado_2024_ENG
#
# 🔍 Running Stage2B for: management_board_report_on_activity_of_enea_and_enea_group
# Page 200: saved page_200_tbl01_Camelot-Stream_conf13.csv, score=49.07
# Page 201: saved page_201_tbl01_Camelot-Stream_conf-23.csv, score=22.62
# Page 203: saved page_203_tbl01_Camelot-Stream_conf45.csv, score=25.20
# Page 204: saved page_204_tbl01_Camelot-Stream_conf-28.csv, score=11.76
# Page 205: saved page_205_tbl01_Camelot-Stream_conf69.csv, score=74.94
# Page 206: saved page_206_tbl01_Camelot-Stream_conf65.csv, score=98.49
# Page 207: saved page_207_tbl01_Camelot-Stream_conf48.csv, score=21.14
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/management_board_report_on_activity_of_enea_and_enea_group
#
# 🔍 Running Stage2B for: management-board-report-on-cd-projekt-group-activities-in-2024
# Page 139: saved page_139_tbl01_Camelot-Stream_conf82.csv, score=37.81
# Page 140: saved page_140_tbl01_Camelot-Stream_conf77.csv, score=42.38
# Page 141: saved page_141_tbl01_Camelot-Stream_conf71.csv, score=13.66
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/management-board-report-on-cd-projekt-group-activities-in-2024
#
# 🔍 Running Stage2B for: OMV Combined Annual Report 2024
# Page 110: saved page_110_tbl01_Camelot-Stream_conf-33.csv, score=-7.54
# Page 111: saved page_111_tbl01_Camelot-Stream_conf-29.csv, score=6.89
# Page 113: saved page_113_tbl01_Camelot-Stream_conf-34.csv, score=-10.52
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/OMV Combined Annual Report 2024
#
# 🔍 Running Stage2B for: Orsted Annual Report 2024
# Page 60: saved page_060_tbl01_Camelot-Stream_conf48.csv, score=40.94
# Page 61: saved page_061_tbl01_Camelot-Stream_conf66.csv, score=65.40
# Page 62: saved page_062_tbl01_Camelot-Stream_conf68.csv, score=47.36
# Page 63: saved page_063_tbl02_Camelot-Stream_conf50.csv, score=30.95
# Page 64: saved page_064_tbl01_Camelot-Stream_conf86.csv, score=-0.05
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Orsted Annual Report 2024
#
# 🔍 Running Stage2B for: PhilipsFullAnnualReport2024-English
# Page 243: saved page_243_tbl02_Camelot-Stream_conf65.csv, score=11.21
# Page 244: saved page_244_tbl02_Camelot-Stream_conf65.csv, score=36.77
# Page 246: saved page_246_tbl02_Camelot-Stream_conf57.csv, score=12.65
# Page 247: saved page_247_tbl02_Camelot-Stream_conf61.csv, score=30.76
# Page 249: saved page_249_tbl03_Camelot-Stream_conf43.csv, score=-5.74
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/PhilipsFullAnnualReport2024-English
#
# 🔍 Running Stage2B for: Randstad_Annual_Report_2024_0
# Page 142: saved page_142_tbl02_Camelot-Stream_conf85.csv, score=50.83
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Randstad_Annual_Report_2024_0
#
# 🔍 Running Stage2B for: RFA_ELO_2024_EN-1
# Page 32: saved page_032_tbl01_Camelot-Stream_conf66.csv, score=162.10
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/RFA_ELO_2024_EN-1
#
# 🔍 Running Stage2B for: sopra_steria_urd_2024_en_opti
# Page 233: saved page_233_tbl01_Camelot-Stream_conf28.csv, score=8.89
# Page 234: saved page_234_tbl01_Camelot-Stream_conf32.csv, score=45.42
# Page 235: saved page_235_tbl01_Camelot-Stream_conf27.csv, score=63.02
# Page 236: saved page_236_tbl01_Camelot-Stream_conf34.csv, score=60.01
# Page 237: saved page_237_tbl01_Camelot-Stream_conf27.csv, score=16.32
# Page 238: saved page_238_tbl01_Camelot-Stream_conf65.csv, score=19.86
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/sopra_steria_urd_2024_en_opti
#
# 🔍 Running Stage2B for: Stellantis-NV-20241231-Annual-Report
# Page 269: saved page_269_tbl02_Camelot-Stream_conf87.csv, score=43.41
# Page 270: saved page_270_tbl01_Camelot-Stream_conf88.csv, score=55.51
# Page 271: saved page_271_tbl01_Camelot-Stream_conf91.csv, score=52.52
# Page 272: saved page_272_tbl01_Camelot-Stream_conf86.csv, score=19.21
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Stellantis-NV-20241231-Annual-Report
#
# 🔍 Running Stage2B for: Terna_2024_Annual_Report_8dd871205a435e0
# Page 165: saved page_165_tbl01_Camelot-Stream_conf-34.csv, score=10.87
# Page 166: saved page_166_tbl02_Camelot-Stream_conf36.csv, score=43.90
# Page 167: saved page_167_tbl01_Camelot-Stream_conf40.csv, score=52.80
# Page 168: saved page_168_tbl01_Camelot-Stream_conf37.csv, score=59.94
# Page 169: saved page_169_tbl01_Camelot-Stream_conf37.csv, score=64.43
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Terna_2024_Annual_Report_8dd871205a435e0
#
# 🔍 Running Stage2B for: TomTom_Annual Report 2024 (PDF Version)
# Page 93: saved page_093_tbl01_Camelot-Stream_conf68.csv, score=23.70
# Page 94: saved page_094_tbl01_Camelot-Stream_conf67.csv, score=52.81
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/TomTom_Annual Report 2024 (PDF Version)
#
# 🔍 Running Stage2B for: UniCredit
# Page 178: saved page_178_tbl02_Camelot-Stream_conf43.csv, score=54.35
# Page 179: saved page_179_tbl02_Camelot-Stream_conf41.csv, score=92.38
# Page 180: saved page_180_tbl02_Camelot-Stream_conf50.csv, score=58.33
# Page 181: saved page_181_tbl02_Camelot-Stream_conf37.csv, score=77.36
# Page 182: saved page_182_tbl02_Camelot-Stream_conf44.csv, score=51.34
# Page 183: saved page_183_tbl03_Camelot-Stream_conf46.csv, score=108.94
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/UniCredit
#
# 🔍 Running Stage2B for: upm-annual-report-2024
# Page 180: saved page_180_tbl01_Camelot-Stream_conf56.csv, score=196.06
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/upm-annual-report-2024
#
# 🔍 Running Stage2B for: Valeo_2024-Universal-registration-document
# Page 309: saved page_309_tbl01_Camelot-Stream_conf80.csv, score=58.82
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Valeo_2024-Universal-registration-document
#
# 🔍 Running Stage2B for: vattenfall-annual-and-sustainability-report-2024
# Page 131: saved page_131_tbl01_Camelot-Stream_conf82.csv, score=11.44
# Page 132: saved page_132_tbl01_Camelot-Stream_conf72.csv, score=177.39
# Page 133: saved page_133_tbl01_Camelot-Stream_conf55.csv, score=115.83
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/vattenfall-annual-and-sustainability-report-2024
#
# 🔍 Running Stage2B for: Veolia_2024_URD
# Page 309: saved page_309_tbl01_Camelot-Stream_conf65.csv, score=47.85
# Page 310: saved page_310_tbl03_Camelot-Stream_conf59.csv, score=63.43
# Page 311: saved page_311_tbl01_Camelot-Stream_conf63.csv, score=60.99
# Page 312: saved page_312_tbl01_Camelot-Stream_conf41.csv, score=22.17
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Veolia_2024_URD
#
# 🔍 Running Stage2B for: verbund-integrated-annual-report-2024-englisch-final-1
# Page 192: saved page_192_tbl01_Camelot-Stream_conf61.csv, score=16.41
# Page 193: saved page_193_tbl01_Camelot-Stream_conf91.csv, score=62.96
# Page 194: saved page_194_tbl01_Camelot-Stream_conf88.csv, score=58.44
# Page 195: saved page_195_tbl01_Camelot-Stream_conf81.csv, score=52.44
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/verbund-integrated-annual-report-2024-englisch-final-1
#
# 🔍 Running Stage2B for: Vestas Annual Report 2024
# Page 212: saved page_212_tbl01_Camelot-Stream_conf85.csv, score=103.31
# Page 213: saved page_213_tbl01_Camelot-Stream_conf65.csv, score=85.79
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Vestas Annual Report 2024
#
# 🔍 Running Stage2B for: vinci-2024-universal-registration-document
# Page 432: saved page_432_tbl01_Camelot-Stream_conf94.csv, score=106.92
# Page 433: saved page_433_tbl01_Camelot-Stream_conf63.csv, score=70.44
# Page 434: saved page_434_tbl01_Camelot-Stream_conf79.csv, score=109.98
# Page 435: saved page_435_tbl01_Camelot-Stream_conf61.csv, score=17.14
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/vinci-2024-universal-registration-document
#
# 🔍 Running Stage2B for: Volkswagen
# Page 447: saved page_447_tbl02_Camelot-Stream_conf60.csv, score=26.22
# Page 448: saved page_448_tbl01_Camelot-Stream_conf83.csv, score=55.20
# Page 449: saved page_449_tbl01_Camelot-Stream_conf78.csv, score=32.71
# Page 450: saved page_450_tbl01_Camelot-Stream_conf85.csv, score=19.62
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Volkswagen
#
# 🔍 Running Stage2B for: WithSecure_Annual_Report_2024
# Page 41: saved page_041_tbl01_Camelot-Stream_conf83.csv, score=34.87
# Page 43: saved page_043_tbl04_Camelot-Stream_conf48.csv, score=61.81
# Page 44: saved page_044_tbl03_Camelot-Stream_conf48.csv, score=69.84
# Page 45: saved page_045_tbl05_Camelot-Stream_conf49.csv, score=80.87
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/WithSecure_Annual_Report_2024
#
# 🔍 Running Stage2B for: Wolters_Kluwer_2024_Annual_Report
# Page 140: saved page_140_tbl01_Camelot-Stream_conf42.csv, score=17.68
# Page 141: saved page_141_tbl01_Camelot-Stream_conf54.csv, score=53.79
# Page 142: saved page_142_tbl01_Camelot-Stream_conf50.csv, score=26.18
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Wolters_Kluwer_2024_Annual_Report
#
# 🔍 Running Stage2B for: Zabka-Group-2024-AR-Full-year
# Page 119: saved page_119_tbl01_Camelot-Stream_conf40.csv, score=20.29
# Page 120: saved page_120_tbl01_Camelot-Stream_conf30.csv, score=4.34
# Page 121: saved page_121_tbl01_Camelot-Stream_conf30.csv, score=26.87
# Page 122: saved page_122_tbl01_Camelot-Stream_conf33.csv, score=5.45
# Page 123: saved page_123_tbl02_Camelot-Stream_conf35.csv, score=7.88
# ✅ Saved filtered tables to: /Users/valeriiaklynna/Documents/GitHub/bachelor-thesis-group32-new/bachelor-thesis-group32-folder/2_output/filtered_tables/Zabka-Group-2024-AR-Full-year
