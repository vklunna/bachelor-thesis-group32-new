# %%
import pandas as pd
import fitz
import re
from pathlib import Path
import unicodedata

# %% [markdown]
# Extract text containing only code E

# %%
def normalize_whitespace(text):
    return re.sub(r'\s+', ' ', text).strip()

def normalize_unicode(text):
    return unicodedata.normalize("NFKC", text)

def parse_page_range(text):
    text = str(text)
    numbers = set()
    for part in re.split(r"[;,]", text):
        part = part.strip()
        if re.match(r"^\d+\s*[-–]\s*\d+$", part):
            start, end = map(int, re.split(r"[-–]", part))
            numbers.update(range(start, end + 1))
        elif part.isdigit():
            numbers.add(int(part))
    return numbers

def extract_pdf_text_by_code_and_section(pdf_path):
    pdf_path = Path(pdf_path)
    pdf_stem = pdf_path.stem

    table_path = Path("../2_output/standardized_merged_by_company") / f"{pdf_stem}_standardized_full.csv"
    if not table_path.exists():
        raise FileNotFoundError(f"❌ Cannot find the standardized table at: {table_path}")

    df = pd.read_csv(table_path)
    df.columns = df.columns.str.strip()
    df["Code"] = df["Code"].astype(str).str.strip()
    df["Relevant Pages"] = df["Relevant Pages"].astype(str).str.strip()
    df["Section Reference"] = df["Section Reference"].astype(str).str.strip()
    df["Page Range"] = df["Page Range"].astype(str).str.strip()

    doc = fitz.open(pdf_path)
    output = []

    for i, row in df.iterrows():
        if i == 0:
            continue  # 🆕 Skip the first row unconditionally

        code = row["Code"]
        valid_code = bool(re.search(r"\b(ESRS\s*)?E[-\s]?\d+\b", code, re.IGNORECASE))
        if not valid_code:
            continue

        rel_pages_raw = row["Relevant Pages"]
        section_raw = row["Section Reference"]
        page_range_set = parse_page_range(row.get("Page Range", ""))
        EXPANSION_RANGE = 2

        total_pages = len(doc)
        cutoff_page = int(total_pages * 0.8)

        # ✅ Relevant pages logic
        used_pages = set()
        if rel_pages_raw and pd.notna(rel_pages_raw):
            page_nums = [int(p) for p in re.findall(r"\d+", rel_pages_raw)]
            for p in page_nums:
                if 20 < p <= cutoff_page:
                    for n in range(p - EXPANSION_RANGE, p + EXPANSION_RANGE + 1):
                        if 1 <= n <= cutoff_page:
                            used_pages.add(n)
        for page_num in sorted(used_pages):
            raw_text = doc[page_num - 1].get_text()
            page_text = normalize_whitespace(normalize_unicode(raw_text))
            output.append({
                "Matched Code": code,
                "Relevant Pages (Raw)": rel_pages_raw,
                "Used Pages": page_num,
                "Section Reference": None,
                "Extracted Text": page_text.strip()
            })

        # ✅ Section Reference logic — one output per section string
        if section_raw and pd.notna(section_raw):
            section_list = [s.strip() for s in section_raw.split(",") if s.strip()]
            for sec in section_list:
                matched_pages = set()
                for page_num in range(21, total_pages + 1):
                    if page_num in page_range_set:
                        continue
                    text = doc[page_num - 1].get_text()
                    if re.search(rf"\b{re.escape(sec)}\b", text):
                        print(f"[Section Match ✅] Row {i}, Code='{code}', Section='{sec}', Triggered Page={page_num}")
                        if 20 < page_num <= cutoff_page:
                            for n in range(page_num - EXPANSION_RANGE, page_num + EXPANSION_RANGE + 1):
                                if 1 <= n <= cutoff_page:
                                    matched_pages.add(n)

                if not matched_pages:
                    print(f"[Section Miss ❌] Row {i}, Code='{code}', Section='{sec}' — no matches found.")

                for page_num in sorted(matched_pages):
                    raw_text = doc[page_num - 1].get_text()
                    page_text = normalize_whitespace(normalize_unicode(raw_text))
                    output.append({
                        "Matched Code": code,
                        "Relevant Pages (Raw)": rel_pages_raw,
                        "Used Pages": page_num,
                        "Section Reference": sec,
                        "Extracted Text": page_text.strip()
                    })


    return pd.DataFrame(output)

# %%
pdf_path = "../0_data/pdfs/UniCredit.pdf"
result_df = extract_pdf_text_by_code_and_section(pdf_path)

# %%
result_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#preview
for i, row in result_df.iterrows():
    print(f"\n--- Code: {row['Matched Code']} | Page: {row['Used Pages']} | Section: {row['Section Reference']} ---\n")
    print(row["Extracted Text"][:1000])  # preview first 1000 chars

# %%
#save results in folder extracted_text_indiv
text_only = result_df["Extracted Text"]

company_name = Path(pdf_path).stem.strip()
save_path = Path("../2_output/extracted_text_indiv") / f"{company_name}_extracted_text_only.txt"
save_path.parent.mkdir(parents=True, exist_ok=True)

text_only.to_csv(save_path, index=False, header=False)
print(f"✅ Saved extracted text only to: {save_path}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 #save results in folder extracted_text_indiv
# ----> 2 text_only = result_df["Extracted Text"]
#       4 company_name = Path(pdf_path).stem.strip()
#       5 save_path = Path("../2_output/extracted_text_indiv") / f"{company_name}_extracted_text_only.txt"
#
# File ~/anaconda3/envs/esg-py311/lib/python3.11/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~/anaconda3/envs/esg-py311/lib/python3.11/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'Extracted Text'

# %% [markdown]
# Alternatively, run through all pdfs in excel

# %%
# === Load all report names from Excel ===
REPO_ROOT = Path().resolve()
excel_path = REPO_ROOT.parent / "0_data" / "table_extraction_accuracy2.xlsx"
sheet_name = "suggested weights"
pdf_df = pd.read_excel(excel_path, sheet_name=sheet_name)

# Match full filename with extension
pdf_df = pdf_df.dropna(subset=["pdf_path", "emission level"])
pdf_df["pdf_name"] = pdf_df["pdf_path"].apply(lambda p: Path(p).name)
pdf_names = pdf_df["pdf_name"].unique()
emission_map = dict(zip(pdf_df["pdf_name"], pdf_df["emission level"]))

pdf_folder = Path("../0_data/pdfs")
output_folder = Path("../2_output/extracted_text_indiv")
output_folder.mkdir(parents=True, exist_ok=True)

processed_count = 0
error_count = 0
high_emission_count = 0
low_emission_count = 0

# === Process each matching PDF ===
for pdf_path in pdf_folder.glob("*.pdf"):
    if pdf_path.name in pdf_names:
        try:
            print(f"🔍 Processing: {pdf_path.name}")
            result_df = extract_pdf_text_by_code_and_section(pdf_path)
            text_only = result_df["Extracted Text"]

            save_path = output_folder / f"{pdf_path.stem}_extracted_text_only.txt"
            text_only.to_csv(save_path, index=False, header=False)
            print(f"✅ Saved: {save_path}")
            processed_count += 1

            # Count by emission category
            emission_label = emission_map.get(pdf_path.name, "").strip().lower()
            if emission_label == "high":
                high_emission_count += 1
            elif emission_label == "low":
                low_emission_count += 1

        except Exception as e:
            print(f"❌ Error processing {pdf_path.name}: {e}")
            error_count += 1
    else:
        print(f"⏩ Skipped (not in Excel): {pdf_path.name}")
# Out:
# 🔍 Processing: UniCredit.pdf
# ❌ Error processing UniCredit.pdf: 'Extracted Text'
# 🔍 Processing: AB InBev 2024 Annual Report FINAL_Interactive.pdf
# ❌ Error processing AB InBev 2024 Annual Report FINAL_Interactive.pdf: ❌ Cannot find the standardized table at: ../2_output/standardized_merged_by_company/AB InBev 2024 Annual Report FINAL_Interactive_standardized_full.csv
# 🔍 Processing: Covestro_2024_GB_EN.pdf
# [Section Miss ❌] Row 3, Code='E2', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E3', Section='nan' — no matches found.
# ❌ Error processing Covestro_2024_GB_EN.pdf: 'Extracted Text'
# 🔍 Processing: consolidated-annual-report-endesa-2024.pdf
# ❌ Error processing consolidated-annual-report-endesa-2024.pdf: 'Extracted Text'
# 🔍 Processing: Amorim_RC24_EN.pdf
# ❌ Error processing Amorim_RC24_EN.pdf: 'Extracted Text'
# 🔍 Processing: Valeo_2024-Universal-registration-document.pdf
# [Section Match ✅] Row 1, Code='E1-3', Section='4.2.3.6', Triggered Page=210
# [Section Match ✅] Row 1, Code='E1-3', Section='4.2.3.6', Triggered Page=226
# [Section Match ✅] Row 1, Code='E1-3', Section='4.2.3.6', Triggered Page=230
# [Section Match ✅] Row 1, Code='E1-3', Section='4.2.3.6', Triggered Page=301
# [Section Match ✅] Row 1, Code='E1-3', Section='4.2.3.6', Triggered Page=311
# [Section Match ✅] Row 1, Code='E1-3', Section='4.2.3.6', Triggered Page=312
# [Section Match ✅] Row 1, Code='E1-3', Section='4.2.3.6', Triggered Page=325
# [Section Match ✅] Row 1, Code='E1-3', Section='4.2.3.6', Triggered Page=328
# [Section Match ✅] Row 2, Code='E1-6', Section='4.2.3.9', Triggered Page=210
# [Section Match ✅] Row 2, Code='E1-6', Section='4.2.3.9', Triggered Page=228
# [Section Match ✅] Row 2, Code='E1-6', Section='4.2.3.9', Triggered Page=233
# [Section Match ✅] Row 2, Code='E1-6', Section='4.2.3.9', Triggered Page=236
# [Section Match ✅] Row 2, Code='E1-6', Section='4.2.3.9', Triggered Page=301
# [Section Match ✅] Row 2, Code='E1-6', Section='4.2.3.9', Triggered Page=311
# [Section Match ✅] Row 2, Code='E1-6', Section='4.2.3.9', Triggered Page=312
# [Section Match ✅] Row 2, Code='E1-6', Section='4.2.3.9', Triggered Page=322
# [Section Match ✅] Row 2, Code='E1-6', Section='4.2.3.9', Triggered Page=327
# [Section Match ✅] Row 2, Code='E1-6', Section='4.2.3.9', Triggered Page=328
# [Section Match ✅] Row 2, Code='E1-6', Section='4.2.3.9', Triggered Page=333
# [Section Match ✅] Row 2, Code='E1-6', Section='4.2.3.9', Triggered Page=335
# [Section Match ✅] Row 3, Code='E2-2', Section='4.2.4.3', Triggered Page=241
# [Section Match ✅] Row 3, Code='E2-2', Section='4.2.4.3', Triggered Page=302
# [Section Match ✅] Row 3, Code='E2-2', Section='4.2.4.3', Triggered Page=312
# [Section Match ✅] Row 3, Code='E2-2', Section='4.2.4.3', Triggered Page=323
# [Section Miss ❌] Row 4, Code='E2-3', Section='nan' — no matches found.
# [Section Match ✅] Row 5, Code='E3-2', Section='4.2.5.3', Triggered Page=248
# [Section Match ✅] Row 5, Code='E3-2', Section='4.2.5.3', Triggered Page=302
# [Section Match ✅] Row 5, Code='E3-2', Section='4.2.5.3', Triggered Page=324
# [Section Miss ❌] Row 6, Code='E3-3', Section='nan' — no matches found.
# [Section Match ✅] Row 7, Code='E3-4', Section='4.2.5.5', Triggered Page=249
# [Section Match ✅] Row 7, Code='E3-4', Section='4.2.5.5', Triggered Page=302
# [Section Match ✅] Row 7, Code='E3-4', Section='4.2.5.5', Triggered Page=326
# [Section Match ✅] Row 7, Code='E3-4', Section='4.2.5.5', Triggered Page=336
# [Section Match ✅] Row 8, Code='E4-3', Section='4.2.6.4', Triggered Page=213
# [Section Match ✅] Row 8, Code='E4-3', Section='4.2.6.4', Triggered Page=252
# [Section Match ✅] Row 8, Code='E4-3', Section='4.2.6.4', Triggered Page=303
# [Section Match ✅] Row 8, Code='E4-3', Section='4.2.6.4', Triggered Page=311
# [Section Match ✅] Row 8, Code='E4-3', Section='4.2.6.4', Triggered Page=313
# ✅ Saved: ../2_output/extracted_text_indiv/Valeo_2024-Universal-registration-document_extracted_text_only.txt
# 🔍 Processing: fingrid_oyj_annual_report_2024.pdf
# [Section Miss ❌] Row 1, Code='E1-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 2, Code='E1-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 3, Code='E1-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E1-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E1-6', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E1-7', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E1-8', Section='nan' — no matches found.
# [Section Miss ❌] Row 8, Code='E1-9', Section='nan' — no matches found.
# [Section Miss ❌] Row 9, Code='E4-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 10, Code='E4-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 11, Code='E4-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 12, Code='E4-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 13, Code='E5-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 14, Code='E5-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 15, Code='E5-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 16, Code='E5-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 17, Code='E5-6', Section='nan' — no matches found.
# ❌ Error processing fingrid_oyj_annual_report_2024.pdf: 'Extracted Text'
# 🔍 Processing: bn_annual_report_2024.pdf
# [Section Miss ❌] Row 1, Code='E2', Section='nan' — no matches found.
# [Section Miss ❌] Row 2, Code='E4', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/bn_annual_report_2024_extracted_text_only.txt
# 🔍 Processing: 6-2024-KPN-Integrated-Annual-Report.pdf
# ❌ Error processing 6-2024-KPN-Integrated-Annual-Report.pdf: 'Extracted Text'
# 🔍 Processing: allianz-group-annual-report-2024.pdf
# [Section Miss ❌] Row 1, Code='E1', Section='nan' — no matches found.
# [Section Miss ❌] Row 2, Code='E1-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 3, Code='E1-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E1-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E1-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E1-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E1-6', Section='nan' — no matches found.
# [Section Miss ❌] Row 8, Code='E2', Section='nan' — no matches found.
# [Section Miss ❌] Row 9, Code='E2-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 10, Code='E2-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 11, Code='E2-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 12, Code='E3', Section='nan' — no matches found.
# ❌ Error processing allianz-group-annual-report-2024.pdf: 'Extracted Text'
# 🔍 Processing: upm-annual-report-2024.pdf
# [Section Miss ❌] Row 1, Code='E1-3', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/upm-annual-report-2024_extracted_text_only.txt
# 🔍 Processing: Austrian Post Annual Report 2024.pdf
# [Section Miss ❌] Row 3, Code='E1', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E1-6', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E2', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E5', Section='nan' — no matches found.
# ❌ Error processing Austrian Post Annual Report 2024.pdf: 'Extracted Text'
# 🔍 Processing: adidas-ar24.pdf
# [Section Miss ❌] Row 3, Code='E1', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E2', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E3', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E4', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E5', Section='nan' — no matches found.
# ❌ Error processing adidas-ar24.pdf: 'Extracted Text'
# 🔍 Processing: DHL-Group-2024-Annual-Report.pdf
# [Section Miss ❌] Row 3, Code='E1-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E1-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E1-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E1-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E1-6', Section='nan' — no matches found.
# [Section Miss ❌] Row 8, Code='E1-7', Section='nan' — no matches found.
# [Section Miss ❌] Row 9, Code='E1-8', Section='nan' — no matches found.
# [Section Miss ❌] Row 10, Code='E1-9', Section='nan' — no matches found.
# [Section Match ✅] Row 11, Code='E4-2', Section='paragraph 24', Triggered Page=122
# [Section Match ✅] Row 12, Code='E5-5', Section='paragraph 37', Triggered Page=120
# [Section Miss ❌] Row 12, Code='E5-5', Section='paragraph 39' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/DHL-Group-2024-Annual-Report_extracted_text_only.txt
# 🔍 Processing: annual-report-2024-equinor-compressed.pdf
# ❌ Error processing annual-report-2024-equinor-compressed.pdf: 'Extracted Text'
# ⏩ Skipped (not in Excel): consolidated-annual-report-endesa-2024 copy.pdf
# 🔍 Processing: finnair-financial-information-2024.pdf
# [Section Miss ❌] Row 1, Code='E1-6', Section='nan' — no matches found.
# [Section Miss ❌] Row 2, Code='E1-7', Section='nan' — no matches found.
# [Section Miss ❌] Row 3, Code='E2-6', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E3-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E4', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E4-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E4-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 8, Code='E5-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 9, Code='E5-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 10, Code='E5-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 11, Code='E5-4', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/finnair-financial-information-2024_extracted_text_only.txt
# 🔍 Processing: verbund-integrated-annual-report-2024-englisch-final-1.pdf
# [Section Miss ❌] Row 3, Code='E1', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E1-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E1-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E1-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E1-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 8, Code='E1-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 9, Code='E1-6', Section='nan' — no matches found.
# [Section Miss ❌] Row 10, Code='E1-8', Section='nan' — no matches found.
# [Section Miss ❌] Row 11, Code='E1-9', Section='nan' — no matches found.
# [Section Miss ❌] Row 12, Code='E2', Section='nan' — no matches found.
# [Section Miss ❌] Row 13, Code='E2-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 14, Code='E2-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 15, Code='E2-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 16, Code='E2-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 17, Code='E3', Section='nan' — no matches found.
# [Section Miss ❌] Row 18, Code='E3-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 19, Code='E3-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 20, Code='E3-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 21, Code='E3-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 22, Code='E3-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 23, Code='E4', Section='nan' — no matches found.
# [Section Miss ❌] Row 24, Code='E4-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 25, Code='E4-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 26, Code='E4-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 27, Code='E4-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 28, Code='E4-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 29, Code='E4-6', Section='nan' — no matches found.
# [Section Miss ❌] Row 30, Code='E5', Section='nan' — no matches found.
# [Section Miss ❌] Row 31, Code='E5-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 32, Code='E5-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 33, Code='E5-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 34, Code='E5-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 35, Code='E5-5', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/verbund-integrated-annual-report-2024-englisch-final-1_extracted_text_only.txt
# 🔍 Processing: f10e19e9-3289-43e1-85cc-5449908cf864.pdf
# [Section Match ✅] Row 3, Code='E1-1', Section='4.2.2.2 The transition plan', Triggered Page=155
# [Section Match ✅] Row 4, Code='E1-2', Section='4.2.2.2 The transition plan', Triggered Page=155
# [Section Match ✅] Row 4, Code='E1-2', Section='4.2.2.3 Focus on taking climate risks into account', Triggered Page=206
# [Section Match ✅] Row 5, Code='E1-3', Section='4.2.2.4 The Group’s carbon footprint', Triggered Page=155
# [Section Match ✅] Row 6, Code='E1-4', Section='4.2.2.4 The Group’s carbon footprint', Triggered Page=155
# [Section Match ✅] Row 7, Code='E1-5', Section='4.2.2.4 The Group’s carbon footprint', Triggered Page=155
# [Section Match ✅] Row 8, Code='E1-6', Section='4.2.2.4 The Group’s carbon footprint', Triggered Page=155
# [Section Match ✅] Row 9, Code='E1-7', Section='4.2.2.4 The Group’s carbon footprint', Triggered Page=155
# [Section Match ✅] Row 10, Code='E1-8', Section='4.2.2.4 The Group’s carbon footprint', Triggered Page=155
# [Section Match ✅] Row 11, Code='E3-1', Section='4.2.4.2 Policies', Triggered Page=155
# [Section Match ✅] Row 11, Code='E3-1', Section='4.2.4.2 Policies', Triggered Page=258
# [Section Match ✅] Row 11, Code='E3-1', Section='4.2.4.2 Policies', Triggered Page=260
# [Section Match ✅] Row 11, Code='E3-1', Section='actions and targets relating to banking activities', Triggered Page=206
# [Section Match ✅] Row 12, Code='E3-2', Section='4.2.4.2 Policies', Triggered Page=155
# [Section Match ✅] Row 12, Code='E3-2', Section='4.2.4.2 Policies', Triggered Page=258
# [Section Match ✅] Row 12, Code='E3-2', Section='4.2.4.2 Policies', Triggered Page=260
# [Section Match ✅] Row 12, Code='E3-2', Section='actions and targets relating to banking activities', Triggered Page=206
# [Section Match ✅] Row 13, Code='E3-3', Section='4.2.4.2 Policies', Triggered Page=155
# [Section Match ✅] Row 13, Code='E3-3', Section='4.2.4.2 Policies', Triggered Page=258
# [Section Match ✅] Row 13, Code='E3-3', Section='4.2.4.2 Policies', Triggered Page=260
# [Section Match ✅] Row 13, Code='E3-3', Section='actions and targets relating to banking activities', Triggered Page=206
# [Section Match ✅] Row 14, Code='E3-4', Section='4.2.4.3 Water consumption at Group sites', Triggered Page=155
# [Section Miss ❌] Row 15, Code='E4-1', Section='4.2.3.1 The transition plan' — no matches found.
# [Section Miss ❌] Row 16, Code='E4-2', Section='nan' — no matches found.
# [Section Match ✅] Row 17, Code='E4-3', Section='4.2.3.4 Policies', Triggered Page=258
# [Section Match ✅] Row 17, Code='E4-3', Section='4.2.3.4 Policies', Triggered Page=260
# [Section Miss ❌] Row 17, Code='E4-3', Section='actions and targets relating to financial' — no matches found.
# [Section Miss ❌] Row 18, Code='E4-4', Section='4.3.2.2.1 Own workforce' — no matches found.
# [Section Miss ❌] Row 18, Code='E4-4', Section='4.3.2.2 Internal communication and' — no matches found.
# [Section Match ✅] Row 19, Code='E4-5', Section='4.2.3.5 Impacts and actions related to Group', Triggered Page=155
# ✅ Saved: ../2_output/extracted_text_indiv/f10e19e9-3289-43e1-85cc-5449908cf864_extracted_text_only.txt
# 🔍 Processing: entire-full-report-basf-ar24.pdf
# [Section Miss ❌] Row 3, Code='E1', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E2', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E3', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E4', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E5', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/entire-full-report-basf-ar24_extracted_text_only.txt
# 🔍 Processing: Cenergy-Annual_Report_2024.pdf
# [Section Miss ❌] Row 3, Code='E5', Section='nan' — no matches found.
# ❌ Error processing Cenergy-Annual_Report_2024.pdf: 'Extracted Text'
# 🔍 Processing: Bureau-Veritas_Universal_Registration_Document_2024_16.3_Mo.pdf
# ❌ Error processing Bureau-Veritas_Universal_Registration_Document_2024_16.3_Mo.pdf: 'Extracted Text'
# 🔍 Processing: annual-report-2024-data.pdf
# [Section Miss ❌] Row 3, Code='E1-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E1-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E1-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E1-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E1-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 8, Code='E1-6', Section='nan' — no matches found.
# [Section Miss ❌] Row 9, Code='E1-7', Section='nan' — no matches found.
# [Section Miss ❌] Row 10, Code='E1-8', Section='nan' — no matches found.
# [Section Miss ❌] Row 11, Code='E2', Section='nan' — no matches found.
# [Section Miss ❌] Row 12, Code='E2-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 13, Code='E2-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 14, Code='E2-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 15, Code='E2-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 16, Code='E3', Section='nan' — no matches found.
# [Section Miss ❌] Row 17, Code='E4', Section='nan' — no matches found.
# [Section Miss ❌] Row 18, Code='E4-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 19, Code='E4-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 20, Code='E4-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 21, Code='E4-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 22, Code='E5', Section='nan' — no matches found.
# [Section Miss ❌] Row 23, Code='E5-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 24, Code='E5-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 25, Code='E5-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 26, Code='E5-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 27, Code='E5-5', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/annual-report-2024-data_extracted_text_only.txt
# 🔍 Processing: sopra_steria_urd_2024_en_opti.pdf
# [Section Miss ❌] Row 1, Code='E1-3', Section='302-1' — no matches found.
# [Section Miss ❌] Row 2, Code='E1-4', Section='305-4' — no matches found.
# [Section Miss ❌] Row 2, Code='E1-4', Section='308-1' — no matches found.
# [Section Miss ❌] Row 3, Code='E1-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E1-6', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E1-7', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E1-8', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E5-2', Section='306-4' — no matches found.
# [Section Miss ❌] Row 8, Code='E5-3', Section='303-3' — no matches found.
# [Section Miss ❌] Row 9, Code='E5-5', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/sopra_steria_urd_2024_en_opti_extracted_text_only.txt
# 🔍 Processing: Zabka-Group-2024-AR-Full-year.pdf
# [Section Miss ❌] Row 2, Code='E1', Section='nan' — no matches found.
# [Section Miss ❌] Row 3, Code='E4', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/Zabka-Group-2024-AR-Full-year_extracted_text_only.txt
# 🔍 Processing: Randstad_Annual_Report_2024_0.pdf
# ❌ Error processing Randstad_Annual_Report_2024_0.pdf: 'Extracted Text'
# 🔍 Processing: FA_0124_Geschaeftsbericht_EN_RZ_250325_FINAL.pdf
# ❌ Error processing FA_0124_Geschaeftsbericht_EN_RZ_250325_FINAL.pdf: 'Extracted Text'
# 🔍 Processing: Basic-Fit Annual_Report_2024_Webversion.pdf
# [Section Miss ❌] Row 1, Code='E1', Section='nan' — no matches found.
# [Section Match ✅] Row 2, Code='E4-2', Section='paragraph 24', Triggered Page=76
# [Section Miss ❌] Row 3, Code='E5-5', Section='paragraph 37' — no matches found.
# [Section Miss ❌] Row 3, Code='E5-5', Section='paragraph 39' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/Basic-Fit Annual_Report_2024_Webversion_extracted_text_only.txt
# 🔍 Processing: ABN_AMRO___Integrated_Annual_Report_2024.pdf
# ❌ Error processing ABN_AMRO___Integrated_Annual_Report_2024.pdf: 'Extracted Text'
# 🔍 Processing: 2024 Adyen Annual Report.pdf
# ❌ Error processing 2024 Adyen Annual Report.pdf: 'Extracted Text'
# 🔍 Processing: management-board-report-on-cd-projekt-group-activities-in-2024.pdf
# [Section Miss ❌] Row 3, Code='E1', Section='nan' — no matches found.
# ❌ Error processing management-board-report-on-cd-projekt-group-activities-in-2024.pdf: 'Extracted Text'
# 🔍 Processing: Borealis-Group-Annual-Report-2024-EN.pdf
# ❌ Error processing Borealis-Group-Annual-Report-2024-EN.pdf: ❌ Cannot find the standardized table at: ../2_output/standardized_merged_by_company/Borealis-Group-Annual-Report-2024-EN_standardized_full.csv
# 🔍 Processing: Volkswagen.pdf
# [Section Miss ❌] Row 1, Code='E1', Section='nan' — no matches found.
# [Section Miss ❌] Row 2, Code='E2', Section='nan' — no matches found.
# [Section Miss ❌] Row 3, Code='E2-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E4', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E5', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/Volkswagen_extracted_text_only.txt
# 🔍 Processing: Veolia_2024_URD.pdf
# [Section Miss ❌] Row 2, Code='E1', Section='4.1.2.1.6 Governance of the climate' — no matches found.
# [Section Match ✅] Row 3, Code='E1-1', Section='4.1.2.1.2 Aligning Veolia’s trajectory with the', Triggered Page=194
# [Section Match ✅] Row 4, Code='E1-2', Section='4.1.2.1.5 Climate change', Triggered Page=194
# [Section Miss ❌] Row 5, Code='E1-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E1-4', Section='nan' — no matches found.
# [Section Match ✅] Row 7, Code='E1-5', Section='4.1.2.1.7', Triggered Page=197
# [Section Match ✅] Row 7, Code='E1-5', Section='4.1.2.1.7', Triggered Page=205
# [Section Match ✅] Row 7, Code='E1-5', Section='4.1.2.1.7', Triggered Page=499
# [Section Match ✅] Row 8, Code='E1-6', Section='4.1.2.1.7', Triggered Page=197
# [Section Match ✅] Row 8, Code='E1-6', Section='4.1.2.1.7', Triggered Page=205
# [Section Match ✅] Row 8, Code='E1-6', Section='4.1.2.1.7', Triggered Page=499
# [Section Match ✅] Row 9, Code='E1-7', Section='4.1.2.1.4 Helping customers', Triggered Page=194
# [Section Match ✅] Row 10, Code='E1-8', Section='4.1.2.1.2 Aligning Veolia’s trajectory with the', Triggered Page=194
# [Section Match ✅] Row 10, Code='E1-8', Section='4.1.2.1.4 Helping customers', Triggered Page=194
# [Section Match ✅] Row 11, Code='E1-9', Section='4.1.2.1.5 Climate change', Triggered Page=194
# [Section Match ✅] Row 12, Code='E2', Section='4.1.2.2.1', Triggered Page=206
# [Section Miss ❌] Row 13, Code='E2-1', Section='4.1.2.2.2 Pollution emitted by Veolia / A Group operational policy supporting the Business' — no matches found.
# [Section Miss ❌] Row 14, Code='E2-2', Section='4.1.2.2.2 Pollution emitted by Veolia / This operational policy is translated locally into appropriate action' — no matches found.
# [Section Miss ❌] Row 15, Code='E2-3', Section='4.1.2.2.2 Pollution emitted by Veolia / Standard targets defined for the level of pollution' — no matches found.
# [Section Miss ❌] Row 16, Code='E2-4', Section='4.1.2.2.2 Pollution emitted by Veolia / Consolidated' — no matches found.
# [Section Miss ❌] Row 17, Code='E2-5', Section='4.1.2.2.2 Pollution emitted by Veolia / Substances of concern and very high' — no matches found.
# [Section Miss ❌] Row 18, Code='E2-6', Section='4.1.2.2.2 Pollution emitted by Veolia / Financial assessment of pollution' — no matches found.
# [Section Miss ❌] Row 19, Code='E3', Section='nan' — no matches found.
# [Section Miss ❌] Row 20, Code='E3-1', Section='4.1.2.3.2 Optimizing water resource' — no matches found.
# [Section Miss ❌] Row 21, Code='E3-2', Section='4.1.2.3.2 Optimizing water resource' — no matches found.
# [Section Miss ❌] Row 22, Code='E3-3', Section='4.1.2.3.3 Measuring our impact on water' — no matches found.
# [Section Miss ❌] Row 23, Code='E3-4', Section='4.1.2.3.3 Measuring our impact on water' — no matches found.
# [Section Miss ❌] Row 24, Code='E3-5', Section='4.1.2.3.4 Supporting the efforts of municipal customers' — no matches found.
# [Section Miss ❌] Row 24, Code='E3-5', Section='4.1.2.3.5 Supporting the efforts of industrial' — no matches found.
# [Section Miss ❌] Row 25, Code='E4', Section='4.1.2.4.2 Veolia’s commitment to nature / Nature is integral' — no matches found.
# [Section Miss ❌] Row 26, Code='E4-2', Section='4.1.2.4.2 Veolia’s commitment to nature / Incorporating biodiversity within the Group’s risk management' — no matches found.
# [Section Miss ❌] Row 27, Code='E4-3', Section='4.1.2.4.4 Protection and restoration of nature in Veolia’s direct operations and the value' — no matches found.
# [Section Miss ❌] Row 28, Code='E4-4', Section='4.1.2.4.4 Protection and restoration of nature in Veolia’s direct operations and the value' — no matches found.
# [Section Miss ❌] Row 29, Code='E4-5', Section='4.1.2.4.4 Protection and restoration of nature in Veolia’s direct operations and the value' — no matches found.
# [Section Miss ❌] Row 30, Code='E4-6', Section='4.1.2.4.4 Protection and restoration of nature in Veolia’s direct operations and the value' — no matches found.
# [Section Miss ❌] Row 31, Code='E5', Section='nan' — no matches found.
# [Section Miss ❌] Row 32, Code='E5-1', Section='4.1.2.5.2 Develop material and energy' — no matches found.
# [Section Miss ❌] Row 33, Code='E5-2', Section='4.1.2.5.4 Manage circular solutions using resource-related' — no matches found.
# [Section Miss ❌] Row 34, Code='E5-3', Section='4.1.2.5.4 Manage circular solutions using resource-related' — no matches found.
# [Section Miss ❌] Row 35, Code='E5-4', Section='4.1.2.5.4 Manage circular solutions using resource-related' — no matches found.
# [Section Miss ❌] Row 36, Code='E5-5', Section='4.1.2.5.4 Manage circular solutions using resource-related' — no matches found.
# [Section Miss ❌] Row 37, Code='E5-6', Section='4.1.2.5.4 Manage circular solutions using resource-related' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/Veolia_2024_URD_extracted_text_only.txt
# 🔍 Processing: PhilipsFullAnnualReport2024-English.pdf
# [Section Miss ❌] Row 1, Code='E1-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 2, Code='E1-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 3, Code='E1-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E1-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E1-6', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E1-7', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E1-8', Section='nan' — no matches found.
# [Section Miss ❌] Row 8, Code='E1-9', Section='nan' — no matches found.
# [Section Miss ❌] Row 9, Code='E5-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 10, Code='E5-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 11, Code='E5-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 12, Code='E5-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 13, Code='E5-6', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/PhilipsFullAnnualReport2024-English_extracted_text_only.txt
# 🔍 Processing: Annual Report 2024_Zalando SE_EN_250503_s.pdf
# [Section Miss ❌] Row 1, Code='E1', Section='nan' — no matches found.
# [Section Miss ❌] Row 2, Code='E2', Section='nan' — no matches found.
# [Section Miss ❌] Row 3, Code='E3', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E5', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/Annual Report 2024_Zalando SE_EN_250503_s_extracted_text_only.txt
# 🔍 Processing: GB24-gesamt-EN_final.pdf
# ❌ Error processing GB24-gesamt-EN_final.pdf: ❌ Cannot find the standardized table at: ../2_output/standardized_merged_by_company/GB24-gesamt-EN_final_standardized_full.csv
# 🔍 Processing: Orsted Annual Report 2024.pdf
# [Section Miss ❌] Row 1, Code='E1', Section='nan' — no matches found.
# [Section Miss ❌] Row 2, Code='E2', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/Orsted Annual Report 2024_extracted_text_only.txt
# 🔍 Processing: ferrovial-integrated-annual-report-2024-1.pdf
# ❌ Error processing ferrovial-integrated-annual-report-2024-1.pdf: 'Extracted Text'
# 🔍 Processing: Annual Report 2024 - for print.pdf
# [Section Miss ❌] Row 1, Code='E1-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 2, Code='E1-7', Section='nan' — no matches found.
# [Section Miss ❌] Row 3, Code='E1-9', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E3-5', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/Annual Report 2024 - for print_extracted_text_only.txt
# 🔍 Processing: f3bb40f8-e502-409f-b3b3-a61e2954531b.pdf
# [Section Miss ❌] Row 3, Code='E1-6', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E1-7', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E1-8', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E1-9', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E2', Section='nan' — no matches found.
# [Section Miss ❌] Row 8, Code='E3', Section='nan' — no matches found.
# [Section Miss ❌] Row 9, Code='E4', Section='nan' — no matches found.
# [Section Miss ❌] Row 10, Code='E5', Section='nan' — no matches found.
# [Section Miss ❌] Row 11, Code='E5-1', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/f3bb40f8-e502-409f-b3b3-a61e2954531b_extracted_text_only.txt
# 🔍 Processing: BMW-Group-Report-2024-en.pdf
# [Section Match ✅] Row 4, Code='E1', Section='nan', Triggered Page=187
# [Section Match ✅] Row 5, Code='E1-1', Section='nan', Triggered Page=187
# ✅ Saved: ../2_output/extracted_text_indiv/BMW-Group-Report-2024-en_extracted_text_only.txt
# 🔍 Processing: 2024 FBD HOLDINGS ANNUAL REPORT 2024-compressed.pdf
# [Section Miss ❌] Row 3, Code='E1-9', Section='nan' — no matches found.
# ❌ Error processing 2024 FBD HOLDINGS ANNUAL REPORT 2024-compressed.pdf: 'Extracted Text'
# 🔍 Processing: FiskarsGroup_Annual_Report_2024.pdf
# [Section Miss ❌] Row 2, Code='E1', Section='nan' — no matches found.
# [Section Miss ❌] Row 3, Code='E3', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E5', Section='nan' — no matches found.
# ❌ Error processing FiskarsGroup_Annual_Report_2024.pdf: 'Extracted Text'
# 🔍 Processing: airbus_report_of_the_board_of_directors_2024.pdf
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2.2 Transition plan for climate mitigation', Triggered Page=168
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2.2 Transition plan for climate mitigation', Triggered Page=179
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2.2 Transition plan for climate mitigation', Triggered Page=180
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2.2 Transition plan for climate mitigation', Triggered Page=181
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2.2 Transition plan for climate mitigation', Triggered Page=185
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=64
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=140
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=143
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=145
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=147
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=152
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=153
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=154
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=158
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=159
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=165
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=166
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=167
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=168
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=169
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=172
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=174
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=175
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=179
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=180
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=181
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=182
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=183
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=185
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=186
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=187
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=195
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=196
# [Section Match ✅] Row 1, Code='E1', Section='6.2.2', Triggered Page=204
# [Section Match ✅] Row 2, Code='E1-1', Section='6.2.2.2 Transition plan for climate change mitigation', Triggered Page=187
# [Section Match ✅] Row 3, Code='E1-2', Section='6.2.1 Policies', Triggered Page=152
# [Section Match ✅] Row 3, Code='E1-2', Section='6.2.1 Policies', Triggered Page=155
# [Section Match ✅] Row 3, Code='E1-2', Section='6.2.1 Policies', Triggered Page=175
# [Section Match ✅] Row 3, Code='E1-2', Section='6.2.1 Policies', Triggered Page=188
# [Section Match ✅] Row 3, Code='E1-2', Section='6.2.1 Policies', Triggered Page=190
# [Section Match ✅] Row 3, Code='E1-2', Section='6.2.1 Policies', Triggered Page=197
# [Section Match ✅] Row 3, Code='E1-2', Section='6.2.2.4 Policies', Triggered Page=152
# [Section Match ✅] Row 4, Code='E1-3', Section='6.2.2.5 Actions and resources', Triggered Page=153
# [Section Match ✅] Row 5, Code='E1-4', Section='6.2.2.6 Targets', Triggered Page=153
# [Section Match ✅] Row 5, Code='E1-4', Section='6.2.2.6 Targets', Triggered Page=158
# [Section Match ✅] Row 5, Code='E1-4', Section='6.2.2.6 Targets', Triggered Page=166
# [Section Match ✅] Row 6, Code='E1-5', Section='6.2.2.7 Energy Consumption and Mix', Triggered Page=153
# [Section Match ✅] Row 7, Code='E1-6', Section='6.2.2.8 GHG Emissions', Triggered Page=153
# [Section Match ✅] Row 7, Code='E1-6', Section='6.2.2.8 GHG Emissions', Triggered Page=159
# [Section Match ✅] Row 7, Code='E1-6', Section='6.2.2.8 GHG Emissions', Triggered Page=168
# [Section Match ✅] Row 7, Code='E1-6', Section='6.2.2.8 GHG Emissions', Triggered Page=169
# [Section Match ✅] Row 7, Code='E1-6', Section='6.2.2.8 GHG Emissions', Triggered Page=180
# [Section Miss ❌] Row 8, Code='E1-7', Section='6.2.2.9 GHG removals and carbon credits ()' — no matches found.
# [Section Match ✅] Row 8, Code='E1-7', Section='6.2.3.2.4 Metrics', Triggered Page=154
# [Section Miss ❌] Row 9, Code='E1-8', Section='6.2.1.10 Internal carbon pricing' — no matches found.
# [Section Miss ❌] Row 10, Code='E2', Section='nan' — no matches found.
# [Section Miss ❌] Row 11, Code='E2-1', Section='6.2.3.2.1 Policies ()' — no matches found.
# [Section Miss ❌] Row 11, Code='E2-1', Section='6.2.3.3.1 Policies ()' — no matches found.
# [Section Miss ❌] Row 12, Code='E2-2', Section='6.2.3.3.2 Actions and resources ()' — no matches found.
# [Section Match ✅] Row 12, Code='E2-2', Section='6.2.4.3 Actions and resources', Triggered Page=154
# [Section Match ✅] Row 12, Code='E2-2', Section='6.2.4.3 Actions and resources', Triggered Page=194
# [Section Miss ❌] Row 13, Code='E2-3', Section='6.2.3.3.3 Targets ()' — no matches found.
# [Section Match ✅] Row 13, Code='E2-3', Section='6.2.4.4 Targets', Triggered Page=154
# [Section Match ✅] Row 13, Code='E2-3', Section='6.2.4.4 Targets', Triggered Page=195
# [Section Miss ❌] Row 14, Code='E2-4', Section='6.2.3.3.4 Metrics ()' — no matches found.
# [Section Match ✅] Row 14, Code='E2-4', Section='6.2.4.5 Metrics', Triggered Page=150
# [Section Match ✅] Row 14, Code='E2-4', Section='6.2.4.5 Metrics', Triggered Page=154
# [Section Match ✅] Row 14, Code='E2-4', Section='6.2.4.5 Metrics', Triggered Page=160
# [Section Match ✅] Row 14, Code='E2-4', Section='6.2.4.5 Metrics', Triggered Page=193
# [Section Miss ❌] Row 15, Code='E3', Section='nan' — no matches found.
# [Section Miss ❌] Row 16, Code='E3-1', Section='6.2.4.2 Policies ()' — no matches found.
# [Section Match ✅] Row 16, Code='E3-1', Section='6.2.5.4 Policies', Triggered Page=155
# [Section Match ✅] Row 17, Code='E3-2', Section='6.2.4.3 Actions and resources', Triggered Page=153
# [Section Match ✅] Row 17, Code='E3-2', Section='6.2.4.3 Actions and resources', Triggered Page=194
# [Section Match ✅] Row 18, Code='E3-3', Section='6.2.4.4 Targets', Triggered Page=153
# [Section Match ✅] Row 18, Code='E3-3', Section='6.2.4.4 Targets', Triggered Page=195
# [Section Match ✅] Row 19, Code='E3-4', Section='6.2.4.5 Metrics', Triggered Page=150
# [Section Match ✅] Row 19, Code='E3-4', Section='6.2.4.5 Metrics', Triggered Page=153
# [Section Match ✅] Row 19, Code='E3-4', Section='6.2.4.5 Metrics', Triggered Page=160
# [Section Match ✅] Row 19, Code='E3-4', Section='6.2.4.5 Metrics', Triggered Page=193
# [Section Miss ❌] Row 20, Code='E4', Section='nan' — no matches found.
# [Section Miss ❌] Row 21, Code='E4-1', Section='6.2.5.2 Transition plan and consideration of biodiversity and ecosystems in strategy and business model' — no matches found.
# [Section Match ✅] Row 22, Code='E4-2', Section='6.2.1 Policies', Triggered Page=152
# [Section Match ✅] Row 22, Code='E4-2', Section='6.2.1 Policies', Triggered Page=154
# [Section Match ✅] Row 22, Code='E4-2', Section='6.2.1 Policies', Triggered Page=175
# [Section Match ✅] Row 22, Code='E4-2', Section='6.2.1 Policies', Triggered Page=188
# [Section Match ✅] Row 22, Code='E4-2', Section='6.2.1 Policies', Triggered Page=190
# [Section Match ✅] Row 22, Code='E4-2', Section='6.2.1 Policies', Triggered Page=197
# [Section Match ✅] Row 22, Code='E4-2', Section='6.2.5.4 Policies', Triggered Page=152
# [Section Miss ❌] Row 23, Code='E4-3', Section='6.2.5.5 Actions and resources ()' — no matches found.
# [Section Match ✅] Row 23, Code='E4-3', Section='6.2.6.3.1 Actions and resources', Triggered Page=155
# [Section Match ✅] Row 23, Code='E4-3', Section='6.2.6.3.1 Actions and resources', Triggered Page=198
# [Section Miss ❌] Row 24, Code='E4-4', Section='6.2.5.6 Targets and metrics related to biodiversity and ecosystems ()' — no matches found.
# [Section Match ✅] Row 24, Code='E4-4', Section='6.2.6.3.2 Targets', Triggered Page=155
# [Section Match ✅] Row 25, Code='E4-5', Section='6.2.5.6 Targets and metrics related to biodiversity and ecosystems', Triggered Page=153
# [Section Miss ❌] Row 26, Code='E5', Section='nan' — no matches found.
# [Section Miss ❌] Row 27, Code='E5-1', Section='6.2.6.2 Policies ()' — no matches found.
# [Section Match ✅] Row 27, Code='E5-1', Section='6.3.1 Policies', Triggered Page=155
# [Section Match ✅] Row 27, Code='E5-1', Section='6.3.1 Policies', Triggered Page=156
# [Section Match ✅] Row 27, Code='E5-1', Section='6.3.1 Policies', Triggered Page=161
# [Section Match ✅] Row 27, Code='E5-1', Section='6.3.1 Policies', Triggered Page=162
# [Section Match ✅] Row 27, Code='E5-1', Section='6.3.1 Policies', Triggered Page=163
# [Section Match ✅] Row 27, Code='E5-1', Section='6.3.1 Policies', Triggered Page=224
# [Section Match ✅] Row 27, Code='E5-1', Section='6.3.1 Policies', Triggered Page=228
# [Section Match ✅] Row 27, Code='E5-1', Section='6.3.1 Policies', Triggered Page=231
# [Section Match ✅] Row 27, Code='E5-1', Section='6.3.1 Policies', Triggered Page=238
# [Section Miss ❌] Row 28, Code='E5-2', Section='6.2.6.4.1 Actions and resources ()' — no matches found.
# [Section Match ✅] Row 28, Code='E5-2', Section='6.3.2.7.2 Actions and resources', Triggered Page=155
# [Section Match ✅] Row 28, Code='E5-2', Section='6.3.2.7.2 Actions and resources', Triggered Page=221
# [Section Match ✅] Row 28, Code='E5-2', Section='6.3.2.7.2 Actions and resources', Triggered Page=235
# [Section Miss ❌] Row 29, Code='E5-3', Section='6.2.6.4.2 Targets ()' — no matches found.
# [Section Match ✅] Row 29, Code='E5-3', Section='6.3.2.7.3 Targets', Triggered Page=156
# [Section Match ✅] Row 29, Code='E5-3', Section='6.3.2.7.3 Targets', Triggered Page=221
# [Section Miss ❌] Row 30, Code='E5-5', Section='6.2.6.4.3 Metrics ()' — no matches found.
# [Section Match ✅] Row 30, Code='E5-5', Section='6.3.2.6 Characteristics of the undertaking’s employees', Triggered Page=156
# [Section Match ✅] Row 30, Code='E5-5', Section='6.3.2.6 Characteristics of the undertaking’s employees', Triggered Page=182
# [Section Match ✅] Row 30, Code='E5-5', Section='6.3.2.6 Characteristics of the undertaking’s employees', Triggered Page=183
# [Section Match ✅] Row 30, Code='E5-5', Section='6.3.2.6 Characteristics of the undertaking’s employees', Triggered Page=192
# [Section Match ✅] Row 30, Code='E5-5', Section='6.3.2.6 Characteristics of the undertaking’s employees', Triggered Page=195
# ✅ Saved: ../2_output/extracted_text_indiv/airbus_report_of_the_board_of_directors_2024_extracted_text_only.txt
# 🔍 Processing: cfreport - besi-annual-report-2024.pdf
# ❌ Error processing cfreport - besi-annual-report-2024.pdf: ❌ Cannot find the standardized table at: ../2_output/standardized_merged_by_company/cfreport - besi-annual-report-2024_standardized_full.csv
# 🔍 Processing: EXOR 2024 Annual Report.pdf
# [Section Match ✅] Row 1, Code='E1-3', Section='2.2 Emissions reduction', Triggered Page=116
# [Section Match ✅] Row 1, Code='E1-3', Section='2.2 Emissions reduction', Triggered Page=118
# [Section Match ✅] Row 1, Code='E1-3', Section='2.2 Emissions reduction', Triggered Page=126
# [Section Match ✅] Row 1, Code='E1-3', Section='2.2 Emissions reduction', Triggered Page=133
# [Section Match ✅] Row 1, Code='E1-3', Section='2.2 Emissions reduction', Triggered Page=153
# [Section Match ✅] Row 2, Code='E1-4', Section='2.2 Emissions reduction', Triggered Page=116
# [Section Match ✅] Row 2, Code='E1-4', Section='2.2 Emissions reduction', Triggered Page=118
# [Section Match ✅] Row 2, Code='E1-4', Section='2.2 Emissions reduction', Triggered Page=126
# [Section Match ✅] Row 2, Code='E1-4', Section='2.2 Emissions reduction', Triggered Page=133
# [Section Match ✅] Row 2, Code='E1-4', Section='2.2 Emissions reduction', Triggered Page=153
# [Section Miss ❌] Row 3, Code='E1-6', Section='2.2.2 Emission reduction in the value' — no matches found.
# [Section Miss ❌] Row 4, Code='E2', Section='nan' — no matches found.
# [Section Match ✅] Row 5, Code='E2-1', Section='2.3 Environmental', Triggered Page=112
# [Section Match ✅] Row 5, Code='E2-1', Section='2.3 Environmental', Triggered Page=136
# [Section Match ✅] Row 6, Code='E2-2', Section='2.3 Environmental', Triggered Page=112
# [Section Match ✅] Row 6, Code='E2-2', Section='2.3 Environmental', Triggered Page=136
# [Section Match ✅] Row 7, Code='E2-3', Section='2.3 Environmental', Triggered Page=112
# [Section Match ✅] Row 7, Code='E2-3', Section='2.3 Environmental', Triggered Page=136
# [Section Miss ❌] Row 8, Code='E5', Section='nan' — no matches found.
# [Section Match ✅] Row 9, Code='E5-1', Section='2.3 Environmental', Triggered Page=112
# [Section Match ✅] Row 9, Code='E5-1', Section='2.3 Environmental', Triggered Page=136
# [Section Match ✅] Row 10, Code='E5-2', Section='2.3 Environmental', Triggered Page=112
# [Section Match ✅] Row 10, Code='E5-2', Section='2.3 Environmental', Triggered Page=136
# [Section Match ✅] Row 11, Code='E5-3', Section='2.3 Environmental', Triggered Page=112
# [Section Match ✅] Row 11, Code='E5-3', Section='2.3 Environmental', Triggered Page=136
# ✅ Saved: ../2_output/extracted_text_indiv/EXOR 2024 Annual Report_extracted_text_only.txt
# 🔍 Processing: 2025-04-23-Eramet-URD-2024-EN.pdf
# [Section Miss ❌] Row 1, Code='E1', Section='nan' — no matches found.
# [Section Miss ❌] Row 2, Code='E4-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 3, Code='E4-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E4-3', Section='nan' — no matches found.
# ❌ Error processing 2025-04-23-Eramet-URD-2024-EN.pdf: 'Extracted Text'
# 🔍 Processing: 2024 ING Groep NV annual report.pdf
# [Section Miss ❌] Row 3, Code='E1', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E2', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E3', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E4', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E5', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/2024 ING Groep NV annual report_extracted_text_only.txt
# 🔍 Processing: WithSecure_Annual_Report_2024.pdf
# [Section Miss ❌] Row 3, Code='E1', Section='nan' — no matches found.
# ❌ Error processing WithSecure_Annual_Report_2024.pdf: 'Extracted Text'
# 🔍 Processing: OMV Combined Annual Report 2024.pdf
# ❌ Error processing OMV Combined Annual Report 2024.pdf: 'Extracted Text'
# 🔍 Processing: f-secure-annual-report-2024.pdf
# ❌ Error processing f-secure-annual-report-2024.pdf: 'Extracted Text'
# 🔍 Processing: Annual-Report-2024-Enagas.pdf
# ❌ Error processing Annual-Report-2024-Enagas.pdf: ❌ Cannot find the standardized table at: ../2_output/standardized_merged_by_company/Annual-Report-2024-Enagas_standardized_full.csv
# 🔍 Processing: Etteplan.pdf
# ❌ Error processing Etteplan.pdf: 'Extracted Text'
# 🔍 Processing: RFA_ELO_2024_EN-1.pdf
# ❌ Error processing RFA_ELO_2024_EN-1.pdf: 'Extracted Text'
# 🔍 Processing: f5937bce-c119-4d4d-91fd-9306c8d2c744.pdf
# [Section Miss ❌] Row 3, Code='E2', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E2-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E2-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E2-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E2-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 8, Code='E2-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 9, Code='E2-6', Section='nan' — no matches found.
# [Section Miss ❌] Row 10, Code='E3', Section='nan' — no matches found.
# [Section Miss ❌] Row 11, Code='E3-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 12, Code='E3-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 13, Code='E3-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 14, Code='E3-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 15, Code='E3-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 16, Code='E5', Section='nan' — no matches found.
# [Section Miss ❌] Row 17, Code='E5-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 18, Code='E5-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 19, Code='E5-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 20, Code='E5-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 21, Code='E5-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 22, Code='E5-6', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/f5937bce-c119-4d4d-91fd-9306c8d2c744_extracted_text_only.txt
# 🔍 Processing: Stellantis-NV-20241231-Annual-Report.pdf
# [Section Miss ❌] Row 3, Code='E1', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E2', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E3', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E4', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E5', Section='nan' — no matches found.
# ❌ Error processing Stellantis-NV-20241231-Annual-Report.pdf: 'Extracted Text'
# 🔍 Processing: Wolters_Kluwer_2024_Annual_Report.pdf
# ❌ Error processing Wolters_Kluwer_2024_Annual_Report.pdf: 'Extracted Text'
# 🔍 Processing: AR2024_FINAL_en.pdf
# ❌ Error processing AR2024_FINAL_en.pdf: 'Extracted Text'
# ⏩ Skipped (not in Excel): 2024_urd-ven_04032025.pdf
# 🔍 Processing: eri_euroapi2024_urd_en_basse-definition_31march_19h28.pdf
# ❌ Error processing eri_euroapi2024_urd_en_basse-definition_31march_19h28.pdf: 'Extracted Text'
# ⏩ Skipped (not in Excel): Vonovia-SE_Annual-Report-2024.pdf
# 🔍 Processing: Capgemini_-_2025-03-21_-_2024_Universal_Registration_Document.pdf
# [Section Miss ❌] Row 1, Code='E1-2', Section='4.3.3.2 Policy contributing to our net zero' — no matches found.
# [Section Miss ❌] Row 2, Code='E1-3', Section='4.3.3.3 Actions contributing to our net zero' — no matches found.
# [Section Miss ❌] Row 3, Code='E1-4', Section='4.3.3.4 Targets related to climate change' — no matches found.
# [Section Miss ❌] Row 4, Code='E1-5', Section='4.3.3.5 a) Energy consumption and' — no matches found.
# [Section Miss ❌] Row 5, Code='E1-6', Section='4.3.3.5 b) GHG emissions and' — no matches found.
# [Section Miss ❌] Row 6, Code='E1-7', Section='4.3.3.5 c) GHG removals and avoidance' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/Capgemini_-_2025-03-21_-_2024_Universal_Registration_Document_extracted_text_only.txt
# 🔍 Processing: cchbc-iar-2024.pdf.downloadasset.pdf
# [Section Miss ❌] Row 3, Code='E1-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E1-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E1-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E1-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E1-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 8, Code='E1-6', Section='nan' — no matches found.
# [Section Miss ❌] Row 9, Code='E1-7', Section='nan' — no matches found.
# [Section Miss ❌] Row 10, Code='E5-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 11, Code='E5-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 12, Code='E5-6', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/cchbc-iar-2024.pdf.downloadasset_extracted_text_only.txt
# 🔍 Processing: annual_report_2024_bnp_paribas_fortis_en.pdf
# [Section Miss ❌] Row 3, Code='E1', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E1-1', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E1-2', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E1-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E1-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 8, Code='E1-5', Section='nan' — no matches found.
# [Section Miss ❌] Row 9, Code='E1-6', Section='nan' — no matches found.
# [Section Miss ❌] Row 10, Code='E1-7', Section='nan' — no matches found.
# ❌ Error processing annual_report_2024_bnp_paribas_fortis_en.pdf: 'Extracted Text'
# 🔍 Processing: CLARIANE_DEU_2024_UK.pdf
# [Section Miss ❌] Row 1, Code='E1-1', Section='3.3.2.2 Processes and channels for local communities to raise concerns (ESRS and' — no matches found.
# [Section Miss ❌] Row 2, Code='E1-2', Section='nan' — no matches found.
# ✅ Saved: ../2_output/extracted_text_indiv/CLARIANE_DEU_2024_UK_extracted_text_only.txt
# 🔍 Processing: 2025-03-20-rwe-annual-report-2024.pdf
# ❌ Error processing 2025-03-20-rwe-annual-report-2024.pdf: 'Extracted Text'
# 🔍 Processing: vattenfall-annual-and-sustainability-report-2024.pdf
# [Section Miss ❌] Row 1, Code='E5', Section='nan' — no matches found.
# ❌ Error processing vattenfall-annual-and-sustainability-report-2024.pdf: 'Extracted Text'
# 🔍 Processing: Vestas Annual Report 2024.pdf
# ❌ Error processing Vestas Annual Report 2024.pdf: 'Extracted Text'
# 🔍 Processing: Commerzbank_Group_Annual_Report_2024.pdf
# [Section Miss ❌] Row 3, Code='E1-3', Section='nan' — no matches found.
# [Section Miss ❌] Row 4, Code='E1-4', Section='nan' — no matches found.
# [Section Miss ❌] Row 5, Code='E1-6', Section='nan' — no matches found.
# [Section Miss ❌] Row 6, Code='E1-7', Section='nan' — no matches found.
# [Section Miss ❌] Row 7, Code='E1-9', Section='nan' — no matches found.

# %%
# === Summary ===
print(f"\n✅ Done. Total processed: {processed_count} PDF(s)")
print(f"❌ Total errors: {error_count}")
print(f"📊 High-emission reports processed: {high_emission_count}")
print(f"📊 Low-emission reports processed: {low_emission_count}")

# %% [markdown]
# Now create separate txt file for high and low emission firms

# %%
REPO_ROOT = Path().resolve()
excel_path = REPO_ROOT.parent / "0_data" / "table_extraction_accuracy2.xlsx"
sheet_name = "suggested weights"
pdf_df = pd.read_excel(excel_path, sheet_name=sheet_name)

pdf_df = pdf_df[["pdf_path", "emission level"]].dropna()
pdf_df["pdf_name"] = pdf_df["pdf_path"].apply(lambda p: Path(p).stem.strip())
emission_map = dict(zip(pdf_df["pdf_name"], pdf_df["emission level"]))

# === Input and output folders ===
input_folder = Path("../2_output/extracted_text_indiv")
output_folder = Path("../2_output/extracted_text_indiv")
output_folder.mkdir(parents=True, exist_ok=True)

# === Prepare containers ===
grouped = {"High": [], "Low": []}

# === Loop through extracted txt files ===
for file in input_folder.glob("*_extracted_text_only.txt"):
    stem = file.stem.replace("_extracted_text_only", "")
    label = emission_map.get(stem)

    if label in grouped:
        content = file.read_text(encoding="utf-8").strip()
        if content:
            grouped[label].append(f"--- {stem} ---\n{content}")
    else:
        print(f"⚠️ Skipped {stem}: No emission label found")

# === Save grouped files ===
for label, texts in grouped.items():
    out_path = output_folder / f"{label}_Emission.txt"
    out_path.write_text("\n\n".join(texts), encoding="utf-8")
    print(f"✅ Saved grouped file: {out_path}")
# Out:
# ✅ Saved grouped file: ../2_output/extracted_text_indiv/High_Emission.txt
# ✅ Saved grouped file: ../2_output/extracted_text_indiv/Low_Emission.txt

# %% [markdown]
# Devide text on low and high emission ones

# %%
REPO_ROOT = Path().resolve()
excel_path = REPO_ROOT.parent / "0_data" / "table_extraction_accuracy2.xlsx"
sheet_name = "suggested weights"
pdf_df = pd.read_excel(excel_path, sheet_name=sheet_name)

pdf_df = pdf_df[["pdf_path", "emission level"]].dropna()
pdf_df["pdf_name"] = pdf_df["pdf_path"].apply(lambda p: Path(p).stem.strip())
emission_map = dict(zip(pdf_df["pdf_name"], pdf_df["emission level"]))

# === Input and output folders ===
input_folder = Path("../2_output/extracted_text_indiv")
output_folder = Path("../2_output/extracted_text_indiv")
output_folder.mkdir(parents=True, exist_ok=True)

# === Prepare containers ===
grouped = {"High": [], "Low": []}

# === Loop through extracted txt files ===
for file in input_folder.glob("*_extracted_text_only.txt"):
    stem = file.stem.replace("_extracted_text_only", "")
    label = emission_map.get(stem)

    if label in grouped:
        content = file.read_text(encoding="utf-8").strip()
        if content:
            grouped[label].append(f"--- {stem} ---\n{content}")
    else:
        print(f"⚠️ Skipped {stem}: No emission label found")

# === Save grouped files ===
for label, texts in grouped.items():
    out_path = output_folder / f"{label}_Emission.txt"
    out_path.write_text("\n\n".join(texts), encoding="utf-8")
    print(f"✅ Saved grouped file: {out_path}")
# Out:
# ✅ Saved grouped file: ../2_output/extracted_text_indiv/High_Emission.txt
# ✅ Saved grouped file: ../2_output/extracted_text_indiv/Low_Emission.txt
